# %% [markdown]
# # PyTorch Homework
# ## 作業說明
# 這個作業希望以 PyTorch 的框架透過實作讓同學了解基本的讀取資料集、搭建模型以及訓練的過程。
#
# 這次作業分成三大部份及若干小部份，有一些**被註解框起來的區域**以及 **?** 的部份需要完成。
#
# 1. **資料準備 - 30%**
#     + Transformation
#     + Custom dataset definition - 10%
#     + Create datasets - 10%
#     + Create dataloaders - 10%
#
#
# 2. **建立模型 - 35%**
#     + flatten function - 5%
#     + 使用 nn.Module 建立模型 - 10%
#     + 使用 nn.Sequential 建立模型 - 10%
#     + 自己設計模型 - 10%
#
#
# 3. **訓練模型 - 35%**
#     + Loss function & optimizer - 5%
#     + 訓練 - 20%
#         + 完成程式碼 - 10%
#         + 自行設計的模型測試集準確率(只看最後 5 個 epoch 中的 best accuracy) - 10%
#             + 達到 50% baseline - 5%
#             + Bonus: 準確率超過 baseline 越多拿越高 - 5%
#     + 儲存模型 - 5%
#     + 繪製 loss 及 accuracy 圖表 - 5%
#
# ## 作業繳交
# 1. 繳交期限：
#
#
# 2. 繳交方式：
#
#     只需繳交這份完成的 ipynb 檔至 moodle，每個 cell 的執行結果都要顯示出來(訓練過程、loss curves 等等)，會用這些結果評分，不需要上傳訓練好的模型。
#
#     檔案命名格式：學號_姓名_hw2.ipynb (ex: F12345678_王大明_hw2.ipynb)
#     * **格式不對的話會扣 10 分！！！**
#
#
# 3. 有問題請寄信至助教信箱 ne6094041@gs.ncku.edu.tw 或於 TA hour 至資訊新館65601室找助教詢問。
#     + TA hour: 星期一和四 14:00 ~ 16:30

# %% [markdown]
# ## Import

# %%
import os
import os.path as osp

from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

from torchviz import make_dot
# %matplotlib inline

# %% [markdown]
# ## Hyperparamters
# 可以自行新增或調整需要的 hyperparameter

# %%
SEED = 42

# data
DATA_PATH = 'stanford_dog'
BATCH_SIZE = 32
NUM_WORKERS = 4
MEAN, STD = (0.485, 0.456, 0.406), (0.229, 0.224, 0.225) # mean and std for ImageNet

# training
LR = 2e-4
EPOCHS = 100
USE_CUDA = True # use cuda or not
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
PRINT_FREQ = 10

# %% [markdown]
# ## GPU Setting
# 用 ```torch.cuda.is_available()``` 測試系統是否能使用 cuda

# %%
device = 'cpu'
if USE_CUDA and torch.cuda.is_available(): # 若想使用 cuda 且可以使用 cuda
    device = 'cuda'
print(f'Using {device} for training.')
# Out:
# Using cuda for training.

# %% [markdown]
# ## 1. Preparing Dataset
# PyTorch 中處理資料的部份主要由兩種 API 組成:
# + ```Dataset```: 定義如何讀取資料，並對資料做前處理(搭配 ```transforms```)
# + ```DataLoader```: 負責將多個樣本打包成 mini-batch 、處理資料取樣、以 multi-threading 或 multi-processing 的方式讀取資料等等

# %% [markdown]
# ### 1.1 Transformations
# Pytorch 的 ```transforms``` API 包含許多常用的方法，如縮放、剪裁、翻轉、旋轉、自定義 transform 等等，也包含不同影像格式之間與 tensor 的型態轉換。
#
# 每個 transform 方法可以單獨地被套用在影像上，也可以使用 ```Compose()``` 將許多方法組合在一起，並且會自動地照組合順序套用在影像上
#
# 這裡的 transformations 是常見且基本的組合，雖然這裡不需要填寫，但你可以在裡面增加一些 augmentation 幫助後面的模型訓練。

# %%
normalize = transforms.Normalize(mean=MEAN, std=STD)

# a set of common trasnformation combination for training
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize
])

# transformations for testing do not need to do fancy tricks
test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize
])

# %% [markdown]
# ### 1.2 定義 dataset
# 自定義的資料集會繼承 ```Dataset```，並且 overwrite 以下 3 個 function:
# 1. ```__init__```: 建立資料集中樣本的讀取路徑以及 label 清單
# 2. ```__len__```: 回傳資料集大小，即樣本的數量
# 3. ```__getitem__```: 實際讀取資料的 function ，根據給定的 index 讀取影像，並對影像進行 transformation ，最後回傳處理過的影像以及其 label 。
#
# 在這裡，我們會將每張影像的讀取路徑儲存在 ```samples``` 裡，其對應的 label 儲存在 ```labels```中。
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
class DogDataset(Dataset):
    def __init__(self, samples, classes, cls_to_idx, transform=None):
        """
        samples: 儲存每張影像的路徑以及 label 的清單
        classes: 所有類別名稱的清單
        cls_to_idx: 類別和對應 index 的 dict
        transform: 要對影像執行的 transformation
        """
        self.transform = transform
        
        self.classes = classes
        self.cls_to_idx = cls_to_idx
        self.targets = [s[1] for s in samples] # list of labels corresponding to samples
        self.samples = [s[0] for s in samples] # list of sample paths
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        
        ###############################################################################
        # TODO : get the image path and label of the given index from the lists       #
        # Hints:                                                                      #
        # path = ???                                                                  #
        # label = ???                                                                 #
        ###############################################################################
        path = self.samples[idx] 
        label = self.targets[idx]
        ###############################################################################
        #                            END TO DO                                        #
        ###############################################################################

        # load the image using PIL.Image.open()
        img = Image.open(path)
        
        ###############################################################################
        # TODO : apply the transformation on the loaded image                         #
        # Hints:                                                                      #
        # img = ???                                                                   #
        ###############################################################################
        img = self.transform(img)
        ###############################################################################
        #                            END TODO                                         #
        ###############################################################################
        
        
        return img, label

# %% [markdown]
# ### 1.3 Create datasets
# 首先找出所有資料的路徑並儲存成清單
#
# 這裡不用填寫，但需要執行。

# %%
def find_files(folder):
    """
    Getting the list of files and their labels.
    
    Returns:
    classes: list of class names
    cls_to_idx: dict that map class names to their interger labels
    instances: dict that uses labels as keys and the corresponding tuples (samples, # of samples) as values
    """
    # find classes under the folder
    folder_path = os.path.expanduser(folder)
    classes = os.listdir(folder_path) # class list
    cls_to_idx = {name: i for i, name in enumerate(classes)} # {class name: index}
        
    # find files and make list of them
    instances = {}
    for cls in sorted(cls_to_idx.keys()):
        cls_idx = cls_to_idx[cls]
        cls_path = osp.join(folder_path, cls) # path to the class folder
        files = os.listdir(cls_path) # list of images under the class
        items = [(osp.join(cls_path, name), cls_idx) for name in files] # combine them to form complete paths
        instances[cls_idx] = (items, len(items)) # (list of samples of the class, num of images in this class)
        
    return classes, cls_to_idx, instances

# get the list of samples under the folder
classes, cls_to_idx, instances = find_files(DATA_PATH)
print(f'There are {len(classes)} classes and {sum([s[1] for s in instances.values()])} images.')
# Out:
# There are 20 classes and 3633 images.

# %% [markdown]
# #### Split dataset
# 若資料集本身沒有區分訓練集、驗證集或測試集，我們就必須手動分割出這些子集。
#
# 這次作業採用「訓練集:測試集 = 8:2」的分割策略，對每個類別中的樣本都採用這個比例，這裡使用 ```sklearn``` 的 ```train_test_split``` 。
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
train_samples = []
test_samples = []

# iterate through all classes, split the samples and store them in the lists
for cls_idx, cls_samples in instances.items():
    train, test = train_test_split(cls_samples[0], test_size=0.2, random_state=SEED)  # split
    train_samples += train
    test_samples += test
    
# print(test_samples)
###############################################################################
# TODO : use the sample lists to construct train dataset and test dataset     #
# Hints:                                                                      #
# train_dataset = DogDataset(?, ?, ?, ?)                                      #
# test_dataset = DogDataset(?, ?, ?, ?)                                       #
###############################################################################
train_dataset = DogDataset(samples = train_samples, classes = classes, cls_to_idx = cls_to_idx, transform = train_transforms)
test_dataset = DogDataset(samples = test_samples, classes = classes, cls_to_idx = cls_to_idx, transform = test_transforms)
###############################################################################
#                            END TODO                                         #
###############################################################################

print('Size of train dataset: %d, size of test dataset: %d' % (len(train_dataset), len(test_dataset)))
# Out:
# Size of train dataset: 2898, size of test dataset: 735

# %% [markdown]
# ### 1.4 Create dataloaders
# ```DataLoader``` 負責將從 dataset 中得到的東西根據採樣策略 (```sampler```)、batch size 大小 (```batch_size```)、是否打亂資料順序 (```shuffle```)（訓練時通常會打亂），將樣本打包成一個 mini-batch ，並根據 ```num_workers``` 調整讀取資料的所需的資源。
#
# 從 dataloader 中讀取資料的方式為像 python generator 或 list 一樣使用迴圈取出資料，可以在後面的訓練階段中看到。
#
# 請完成以下被註解框起來的區域。

# %%
train_loader = None
test_loader = None

###############################################################################
# TODO : create dataloaders for train dataset and test dataset                #
# Hints:                                                                      #
# train_loader = DataLoader(?, ?, ?, ?)                                       #
# test_loader = DataLoader(?, ?, ?, ?)                                        #
###############################################################################
train_loader = DataLoader(dataset = train_dataset, batch_size = BATCH_SIZE, shuffle = True, num_workers = NUM_WORKERS)
test_loader = DataLoader(dataset = test_dataset, batch_size = BATCH_SIZE, shuffle = True, num_workers = NUM_WORKERS)
###############################################################################
#                            END TODO                                         #
###############################################################################

print(f'There are {len(train_loader)} training batches and {len(test_loader)} testing batches')
# Out:
# There are 91 training batches and 23 testing batches

# %% [markdown]
# ## 2. Model
# PyTorch 的模型（包括基本的 conv, batchnorm 層等等）大部分都是繼承 ```nn.Module```，並且都具備
# + ```__init__```: 定義內部結構，例如 conv, pool 等等。
# + ```forward```: 定義前面的結構操作如何串聯，也就是這些結構的順序，是輸入的張量真正進行計算的 function 。
#
# 用來建立模型的 API 有很多種，包括 ```nn.Module```、```nn.Sequential```、```nn.ModuleList```、```nn.ModuleDict``` 等等。
#
# 這次作業要求以前兩種方法建立模型，分成 2.1 以及 2.2，並在這兩個部分裡完成下面所敘述的模型結構：
# 1. A convolution layer with 64 11*11 filters, stride 4 and padding 2
# 2. ReLU
# 3. A Maxpooling layer with 3*3 kernel and stride 2
# 4. A convolution layer with 128 5*5 filters and padding 2
# 5. ReLU
# 6. A Maxpooling layer with 3*3 kernel and stride 2
# 7. A convolution layer with 256 3*3 filters and padding 1
# 8. ReLU
# 9. A convolution layer with 128 3*3 filters and padding 1
# 10. ReLU
# 11. A convolution layer with 128 3*3 filters and padding 1
# 12. ReLU
# 13. A Maxpooling layer with 3*3 kernel and stride 2
# 14. flatten
# 15. A fully-connected layer that outputs tensor to 1024
# 16. ReLU
# 17. A fully-connected layer that outputs tensor to 256
# 18. ReLU
# 19. A fully-connected layer that outputs tensor to 20

# %% [markdown]
# ### 2.1 flatten function
# Flatten 作用是將 tensor 除了 batch 以外的其他維度全部攤平。
#
# 請完成以下被註解框起來的區域。

# %%
def flatten(x):
    ###############################################################################
    # TODO : flatten the input tensor x with shape (B, C, H, W) to (B, C*H*W)     #
    ###############################################################################    
    # x = torch.flatten(x, start_dim = 1)
    x = x.view(x.shape[0], -1)
    ###############################################################################
    #                            END TODO                                         #
    ###############################################################################
    return x

# %% [markdown]
# ### 2.2 使用 nn.Module 建立模型
# 如同一般定義 python class 的方法，在建構子中定義會用到的 layer ，並在 forward 中定義其之間的操作連結。
#
# 請完成以下被註解框起來的區域。

# %%
class TestModel(nn.Module):
    def __init__(self):
        super(TestModel, self).__init__() # this line must be done first
        ###############################################################################
        # TODO : Define the model described above by specifying the required layers   #
        # Hints:                                                                      #
        # self.conv1 = ?                                                              #
        # self.relu = ?                                                               #
        # self.maxpool1 = ?                                                           #
        # self.conv2 = ?                                                              #
        # ...                                                                         #
        ###############################################################################
        
        # 1
        self.conv1 = nn.Conv2d(3, 64, 11, stride = 4, padding = 2)
        self.relu = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size = 3, stride=2)
        # 2
        self.conv2 = nn.Conv2d(64, 128, 5, padding = 2)
        self.maxpool2 = nn.MaxPool2d(kernel_size = 3, stride=2)
        # 3
        self.conv3 = nn.Conv2d(128, 256, 3, padding = 1)
        # 4
        self.conv4 = nn.Conv2d(256, 128, 3, padding = 1)
        # 5
        self.conv5 = nn.Conv2d(128, 128, 3, padding = 1)
        self.maxpool5 = nn.MaxPool2d(kernel_size = 3, stride=2)
        # linear
        self.linear1 = nn.Linear(4608, 1024)
        self.linear2 = nn.Linear(1024,  256)
        self.linear3 = nn.Linear( 256,   20)
        
        
        
        
        ###############################################################################
        #                            END TO DO                                         #
        ###############################################################################
        
    
    def forward(self, x):
        ###############################################################################
        # TODO : Implement the forward function, you should use the layers            #
        #        defined in __init__ function and connect them                        #
        # Hints:                                                                      #
        # x = self.?(?)                                                               #
        # x = self.?(?)                                                               #
        # ...                                                                         #
        ###############################################################################
        x = self.conv1(x)
        x = self.relu(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.maxpool2(x)
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv5(x)
        x = self.relu(x)
        x = self.maxpool5(x)
        x = flatten(x)
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        ###############################################################################
        #                            END TODO                                         #
        ###############################################################################
        
        return x

x = torch.randn(4, 3, 224, 224)
model = TestModel()
make_dot(model(x), params=dict(model.named_parameters()))
# 可以將畫出來的圖與助教提供的圖對比看看是否一樣或十分相似

# %% [markdown]
# ### 2.3 使用 nn.Sequential 建立模型
# ```nn.Sequential``` 的不同之處在於可以直接從一系列的 layer 建立模型，不需定義 ```__init__``` 也不用定義 ```forward``` ，會自動依序用每一層進行 forward ，相對地，其成員皆需有 ```forward``` 可以呼叫。
#
# 請完成以下被註解框起來的區域。

# %%
# wrap the flatten function
class Flatten(nn.Module):
    def forward(self, x):
        return flatten(x)

model = None
###############################################################################
# TODO : Define the model described above using nn.Sequential                 #
# Hints:                                                                      #
# model = nn.Sequential(...)                                                  #
###############################################################################
model = nn.Sequential(
    # 1
    nn.Conv2d(3, 64, 11, stride = 4, padding = 2),    
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = 3, stride=2),          
    # 2
    nn.Conv2d(64, 128, 5, padding = 2),               
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = 3, stride = 2),          
    # 3
    nn.Conv2d(128, 256, 3, padding = 1),              
    nn.ReLU(),
    # 4
    nn.Conv2d(256, 128, 3, padding = 1),              
    nn.ReLU(),
    # 5
    nn.Conv2d(128, 128, 3, padding = 1),                
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = 3, stride=2),          
    
    Flatten(),
    # linear
    nn.Linear(4608, 1024),
    nn.ReLU(),
    nn.Linear(1024,  256),
    nn.ReLU(),
    nn.Linear( 256,   20)
)            
###############################################################################
#                            END TODO                                         #
###############################################################################

x = torch.randn(4, 3, 224, 224)
make_dot(model(x), params=dict(model.named_parameters()))
# 可以將畫出來的圖與助教提供的圖對比看看是否一樣或十分相似

# %% [markdown]
# ### 2.4 自行設計模型
# 請使用上述任一種方式設計自己的模型(實體化後的模型名稱為 ```mymodel```)，並解釋自己的設計。最後的分類為 20 個類別。
#
# ## **不可以直接呼叫```torchvision.models```中已經寫好的模型，但可以照著論文中的模型架構手刻出來**
#
# ## **不可以使用預訓練過的模型權重作為初始狀態，也就是不能用預訓練的模型再 fine-tune**
#
# 請完成以下被註解框起來的區域。

# %%
# mymodel = None
# ###############################################################################
# # TODO : Design your own model and instantiate as mymodel.                    #
# # Hint:                                                                       #
# # You can start from modifying the model above.                               #
# ###############################################################################
mymodel = nn.Sequential(
                nn.Conv2d(3, 64, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(64, 64, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size = 2, stride = 2),
    
                nn.Conv2d(64, 128, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(128, 128, 3, stride = 1, padding = 1), 
                nn.ReLU(),
                nn.MaxPool2d(kernel_size = 2, stride = 2),
    
                nn.Conv2d(128, 256, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(256, 256, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(256, 256, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size = 2, stride = 2),      # 16
    
                nn.Conv2d(256, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(512, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(512, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size = 2, stride = 2),
                
                nn.Conv2d(512, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(512, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.Conv2d(512, 512, 3, stride = 1, padding = 1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size = 2, stride = 2),
                
                Flatten(),
    
                nn.Linear(7*7*512, 4096),
                nn.ReLU(),
                nn.Dropout(p = 0.5),
                nn.Linear(4096, 4096),
                nn.ReLU(),
                nn.Dropout(p = 0.5),
                nn.Linear(4096, 1024),
                nn.ReLU(),
                nn.Dropout(p = 0.5),
                nn.Linear(1024, 20)
            )   
# ###############################################################################
# #                            END TODO                                         #
# ###############################################################################
x = torch.randn(4, 3, 224, 224)
make_dot(mymodel(x), params=dict(mymodel.named_parameters()))

# %% [markdown]
# #### 解釋寫在這裡
# 由於VGG架構於各種圖像辨識任務的表現都還不錯，因此決定架設常見的VGG16來進行本次任務。
# 由於model層數不淺，加上資料集以深度學習的角度來看算是非常少，所以決定調整EPOCHS及LR來提昇accuracy。

# %% [markdown]
# ## 3 訓練模型

# %% [markdown]
# ### 3.1 設定 loss function 以及 optimizer
# + 對於分類問題，通常使用 cross entropy 就足夠
# + Optimizer 常用的有 SGD, Adam 等等
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
# 使用哪種 model
model = mymodel
print(model)

criterion = None
optimizer = None
###############################################################################
# TODO : Setting up loss function (criterion) and optimizer                   #
###############################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = LR)
###############################################################################
#                            END TODO                                         #
###############################################################################
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU()
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU()
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU()
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU()
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU()
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU()
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU()
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU()
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU()
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU()
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU()
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (31): Flatten()
#   (32): Linear(in_features=25088, out_features=4096, bias=True)
#   (33): ReLU()
#   (34): Dropout(p=0.5, inplace=False)
#   (35): Linear(in_features=4096, out_features=4096, bias=True)
#   (36): ReLU()
#   (37): Dropout(p=0.5, inplace=False)
#   (38): Linear(in_features=4096, out_features=1024, bias=True)
#   (39): ReLU()
#   (40): Dropout(p=0.5, inplace=False)
#   (41): Linear(in_features=1024, out_features=20, bias=True)
# )

# %%
# 這個 cell 不用填

# helper functions
def accuracy(outputs, targets):
    """Compute accuracy"""
    batch_size = targets.size(0)

    pred = outputs.argmax(1)
    correct = pred.eq(targets)
    acc = correct.float().sum(0) / batch_size

    return acc

class AverageMeter(object):
    """A Meter that records numbers and compute the average."""
    def __init__(self):
        self.reset()
    
    def reset(self):
        self.val = 0.0
        self.avg = 0.0
        self.sum = 0.0
        self.count = 0.0
    
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ### 3.2 開始訓練
# 流程：
#
# 訓練階段，在一個 iteration 中，
# 1. 取出 batch 中的資料
# 2. 由模型預測分類結果 (forward)
# 3. 計算 loss
# 4. 清空梯度
# 5. backward 計算梯度
# 6. 更新模型參數
#
# 重複以上動作直到所有 batch 迭代完成後，進入測試階段，使用測試集測試模型表現，計算準確度。
#
# 到這裡是一個 epoch 的動作，重複直到設定的 epoch 數量後結束。
#
# 以下會把每一個 epoch 的訓練和測試部份寫成兩個 function，請完成 ? 的部分。

# %%
def train(epoch, model, loader, criterion, optimizer):
    """This function trains for 1 epoch and returns the epoch loss and accuracy."""
    # recorders
    loss_m = AverageMeter()
    acc_m = AverageMeter()
    
    model.train() # 1. Set model to training mode
    
    for idx, (imgs, labels) in enumerate(loader): # load data
        # put the data to correct device
        imgs, labels = imgs.to(device), labels.to(device)

        # 2. model forward
        outputs = model(imgs)

        # 3. calculate loss
        loss = criterion(outputs, labels)

        # 4. clear optimizer gradients
        optimizer.zero_grad()

        # 5. backward to calculate gradients
        loss.backward()

        # 6. update model parameters
        optimizer.step()
        
        # 7. accuracy
        acc = accuracy(outputs, labels)
        
        # record loss and acc
        loss_m.update(loss.item(), imgs.size(0))
        acc_m.update(acc.item(), imgs.size(0))
        
        # logging
        if (idx >= 0) and (idx % PRINT_FREQ == 0):
            print("[{:3d}/{}] Train Loss {:.3f} Acc {:.3f}".format(
                idx, len(loader), loss_m.val, acc_m.val
            ))
        
    return loss_m.avg, acc_m.avg

# %%
def test(model, loader, criterion):
    """This function tests the model on the test set."""
    # recorders
    loss_m = AverageMeter()
    out_list, y_list = [], []
    
    model.eval() # 1. set model to eval mode
    
    with torch.no_grad(): # no need to compute gradient when testing
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            
            # 2. model forward
            outputs = model(imgs)
            
            # 3. compute loss
            loss = criterion(outputs, labels)
            
            y_list.append(labels)
            out_list.append(outputs)
            loss_m.update(loss.item())
        
        # concat all predictions and answers to compute accuracy
        pred = torch.cat(out_list)
        y = torch.cat(y_list)
        # 4. accuracy
        acc = accuracy(outputs, labels)
    
    return loss_m.avg, acc.item()

# %% [markdown]
# #### Let's GOOOOOO
#
# 請完成以下 ? 處，並執行這個 cell 以開始訓練。

# %%
# move model to GPU if available
if device == 'cuda':
    model.cuda()
  
# for recording
train_loss, test_loss = [], []
train_acc, test_acc = [], []
best_acc = (0, 0.0) # (epoch, acc)
for epoch in range(EPOCHS):
    print("---------------- Epoch {} ----------------".format(epoch+1))
    
    # 1. training
    loss, acc = train(epoch, model, train_loader, criterion, optimizer)
    # saving epoch loss and acc for plotting
    train_loss.append(loss)
    train_acc.append(acc)
    # logging
    print('Epoch {:3d}/{} Train Loss {:.3f} Acc {:.3f}'.format(epoch+1, EPOCHS, loss, acc))
    
    # 2. testing
    print("---------------- Testing ----------------")
    loss, acc = test(model, test_loader, criterion)
    test_loss.append(loss)
    test_acc.append(acc)        
    # logging
    print('Epoch {:3d}/{} Test Loss {:.3f} Acc {:.3f}'.format(epoch+1, EPOCHS, loss, acc))
    
    if acc > best_acc[1]:
        best_acc = (epoch+1, acc)

print('--' * 10)
print('The Best accuracy is {:.3f} at epoch {}'.format(best_acc[1], best_acc[0]))
# Out:
# ---------------- Epoch 1 ----------------
# [  0/91] Train Loss 2.993 Acc 0.125
# [ 10/91] Train Loss 2.994 Acc 0.062
# [ 20/91] Train Loss 2.981 Acc 0.031
# [ 30/91] Train Loss 2.981 Acc 0.125
# [ 40/91] Train Loss 3.050 Acc 0.031
# [ 50/91] Train Loss 2.948 Acc 0.094
# [ 60/91] Train Loss 3.026 Acc 0.000
# [ 70/91] Train Loss 2.995 Acc 0.031
# [ 80/91] Train Loss 2.999 Acc 0.062
# [ 90/91] Train Loss 2.999 Acc 0.000
# Epoch   1/100 Train Loss 2.993 Acc 0.069
# ---------------- Testing ----------------
# Epoch   1/100 Test Loss 2.990 Acc 0.065
# ---------------- Epoch 2 ----------------
# [  0/91] Train Loss 2.990 Acc 0.062
# [ 10/91] Train Loss 2.962 Acc 0.125
# [ 20/91] Train Loss 2.988 Acc 0.156
# [ 30/91] Train Loss 2.999 Acc 0.062
# [ 40/91] Train Loss 2.978 Acc 0.125
# [ 50/91] Train Loss 2.941 Acc 0.125
# [ 60/91] Train Loss 2.951 Acc 0.062
# [ 70/91] Train Loss 2.927 Acc 0.062
# [ 80/91] Train Loss 3.016 Acc 0.031
# [ 90/91] Train Loss 2.892 Acc 0.000
# Epoch   2/100 Train Loss 2.972 Acc 0.069
# ---------------- Testing ----------------
# Epoch   2/100 Test Loss 2.920 Acc 0.161
# ---------------- Epoch 3 ----------------
# [  0/91] Train Loss 2.881 Acc 0.094
# [ 10/91] Train Loss 2.876 Acc 0.094
# [ 20/91] Train Loss 2.864 Acc 0.062
# [ 30/91] Train Loss 2.870 Acc 0.031
# [ 40/91] Train Loss 2.903 Acc 0.031
# [ 50/91] Train Loss 2.816 Acc 0.125
# [ 60/91] Train Loss 2.756 Acc 0.094
# [ 70/91] Train Loss 2.892 Acc 0.094
# [ 80/91] Train Loss 2.694 Acc 0.094
# [ 90/91] Train Loss 2.901 Acc 0.056
# Epoch   3/100 Train Loss 2.886 Acc 0.090
# ---------------- Testing ----------------
# Epoch   3/100 Test Loss 2.833 Acc 0.226
# ---------------- Epoch 4 ----------------
# [  0/91] Train Loss 2.832 Acc 0.125
# [ 10/91] Train Loss 2.934 Acc 0.031
# [ 20/91] Train Loss 2.701 Acc 0.188
# [ 30/91] Train Loss 2.856 Acc 0.125
# [ 40/91] Train Loss 2.855 Acc 0.125
# [ 50/91] Train Loss 2.709 Acc 0.156
# [ 60/91] Train Loss 2.819 Acc 0.125
# [ 70/91] Train Loss 2.776 Acc 0.094
# [ 80/91] Train Loss 2.841 Acc 0.156
# [ 90/91] Train Loss 3.056 Acc 0.056
# Epoch   4/100 Train Loss 2.830 Acc 0.113
# ---------------- Testing ----------------
# Epoch   4/100 Test Loss 2.856 Acc 0.000
# ---------------- Epoch 5 ----------------
# [  0/91] Train Loss 2.928 Acc 0.062
# [ 10/91] Train Loss 2.859 Acc 0.125
# [ 20/91] Train Loss 2.878 Acc 0.219
# [ 30/91] Train Loss 2.822 Acc 0.125
# [ 40/91] Train Loss 2.828 Acc 0.125
# [ 50/91] Train Loss 2.695 Acc 0.219
# [ 60/91] Train Loss 2.848 Acc 0.062
# [ 70/91] Train Loss 2.834 Acc 0.062
# [ 80/91] Train Loss 2.702 Acc 0.188
# [ 90/91] Train Loss 3.047 Acc 0.056
# Epoch   5/100 Train Loss 2.819 Acc 0.117
# ---------------- Testing ----------------
# Epoch   5/100 Test Loss 2.739 Acc 0.194
# ---------------- Epoch 6 ----------------
# [  0/91] Train Loss 2.750 Acc 0.219
# [ 10/91] Train Loss 2.733 Acc 0.062
# [ 20/91] Train Loss 2.967 Acc 0.062
# [ 30/91] Train Loss 2.760 Acc 0.156
# [ 40/91] Train Loss 2.705 Acc 0.156
# [ 50/91] Train Loss 2.763 Acc 0.156
# [ 60/91] Train Loss 2.868 Acc 0.094
# [ 70/91] Train Loss 2.660 Acc 0.188
# [ 80/91] Train Loss 2.766 Acc 0.188
# [ 90/91] Train Loss 2.897 Acc 0.000
# Epoch   6/100 Train Loss 2.760 Acc 0.142
# ---------------- Testing ----------------
# Epoch   6/100 Test Loss 2.655 Acc 0.161
# ---------------- Epoch 7 ----------------
# [  0/91] Train Loss 2.780 Acc 0.094
# [ 10/91] Train Loss 2.995 Acc 0.125
# [ 20/91] Train Loss 2.789 Acc 0.125
# [ 30/91] Train Loss 2.748 Acc 0.062
# [ 40/91] Train Loss 2.934 Acc 0.125
# [ 50/91] Train Loss 2.514 Acc 0.281
# [ 60/91] Train Loss 2.779 Acc 0.094
# [ 70/91] Train Loss 2.576 Acc 0.125
# [ 80/91] Train Loss 2.738 Acc 0.125
# [ 90/91] Train Loss 2.783 Acc 0.111
# Epoch   7/100 Train Loss 2.754 Acc 0.144
# ---------------- Testing ----------------
# Epoch   7/100 Test Loss 2.639 Acc 0.194
# ---------------- Epoch 8 ----------------
# [  0/91] Train Loss 2.623 Acc 0.156
# [ 10/91] Train Loss 2.558 Acc 0.188
# [ 20/91] Train Loss 2.782 Acc 0.062
# [ 30/91] Train Loss 2.774 Acc 0.125
# [ 40/91] Train Loss 2.372 Acc 0.188
# [ 50/91] Train Loss 2.834 Acc 0.094
# [ 60/91] Train Loss 2.763 Acc 0.156
# [ 70/91] Train Loss 2.823 Acc 0.219
# [ 80/91] Train Loss 2.541 Acc 0.156
# [ 90/91] Train Loss 3.270 Acc 0.111
# Epoch   8/100 Train Loss 2.681 Acc 0.160
# ---------------- Testing ----------------
# Epoch   8/100 Test Loss 2.662 Acc 0.129
# ---------------- Epoch 9 ----------------
# [  0/91] Train Loss 2.791 Acc 0.125
# [ 10/91] Train Loss 2.676 Acc 0.125
# [ 20/91] Train Loss 2.825 Acc 0.062
# [ 30/91] Train Loss 2.386 Acc 0.219
# [ 40/91] Train Loss 2.462 Acc 0.156
# [ 50/91] Train Loss 2.625 Acc 0.094
# [ 60/91] Train Loss 2.915 Acc 0.156
# [ 70/91] Train Loss 2.725 Acc 0.094
# [ 80/91] Train Loss 2.746 Acc 0.188
# [ 90/91] Train Loss 2.749 Acc 0.056
# Epoch   9/100 Train Loss 2.663 Acc 0.157
# ---------------- Testing ----------------
# Epoch   9/100 Test Loss 2.569 Acc 0.226
# ---------------- Epoch 10 ----------------
# [  0/91] Train Loss 2.659 Acc 0.250
# [ 10/91] Train Loss 2.598 Acc 0.125
# [ 20/91] Train Loss 2.857 Acc 0.156
# [ 30/91] Train Loss 2.519 Acc 0.219
# [ 40/91] Train Loss 2.560 Acc 0.281
# [ 50/91] Train Loss 2.513 Acc 0.312
# [ 60/91] Train Loss 2.495 Acc 0.125
# [ 70/91] Train Loss 2.423 Acc 0.281
# [ 80/91] Train Loss 2.363 Acc 0.312
# [ 90/91] Train Loss 2.550 Acc 0.167
# Epoch  10/100 Train Loss 2.629 Acc 0.181
# ---------------- Testing ----------------
# Epoch  10/100 Test Loss 2.487 Acc 0.194
# ---------------- Epoch 11 ----------------
# [  0/91] Train Loss 2.762 Acc 0.125
# [ 10/91] Train Loss 2.885 Acc 0.062
# [ 20/91] Train Loss 2.516 Acc 0.062
# [ 30/91] Train Loss 2.569 Acc 0.188
# [ 40/91] Train Loss 2.738 Acc 0.094
# [ 50/91] Train Loss 2.478 Acc 0.250
# [ 60/91] Train Loss 2.839 Acc 0.156
# [ 70/91] Train Loss 2.561 Acc 0.156
# [ 80/91] Train Loss 2.562 Acc 0.219
# [ 90/91] Train Loss 2.584 Acc 0.278
# Epoch  11/100 Train Loss 2.611 Acc 0.191
# ---------------- Testing ----------------
# Epoch  11/100 Test Loss 2.499 Acc 0.161
# ---------------- Epoch 12 ----------------
# [  0/91] Train Loss 2.669 Acc 0.125
# [ 10/91] Train Loss 2.482 Acc 0.188
# [ 20/91] Train Loss 2.633 Acc 0.219
# [ 30/91] Train Loss 2.687 Acc 0.156
# [ 40/91] Train Loss 2.704 Acc 0.219
# [ 50/91] Train Loss 2.355 Acc 0.219
# [ 60/91] Train Loss 2.857 Acc 0.188
# [ 70/91] Train Loss 2.250 Acc 0.281
# [ 80/91] Train Loss 2.661 Acc 0.125
# [ 90/91] Train Loss 2.448 Acc 0.333
# Epoch  12/100 Train Loss 2.569 Acc 0.193
# ---------------- Testing ----------------
# Epoch  12/100 Test Loss 2.439 Acc 0.258
# ---------------- Epoch 13 ----------------
# [  0/91] Train Loss 2.506 Acc 0.188
# [ 10/91] Train Loss 2.581 Acc 0.219
# [ 20/91] Train Loss 2.405 Acc 0.094
# [ 30/91] Train Loss 2.395 Acc 0.250
# [ 40/91] Train Loss 2.796 Acc 0.125
# [ 50/91] Train Loss 2.540 Acc 0.188
# [ 60/91] Train Loss 2.370 Acc 0.281
# [ 70/91] Train Loss 2.584 Acc 0.250
# [ 80/91] Train Loss 3.079 Acc 0.094
# [ 90/91] Train Loss 2.712 Acc 0.167
# Epoch  13/100 Train Loss 2.570 Acc 0.193
# ---------------- Testing ----------------
# Epoch  13/100 Test Loss 2.451 Acc 0.323
# ---------------- Epoch 14 ----------------
# [  0/91] Train Loss 2.674 Acc 0.125
# [ 10/91] Train Loss 2.631 Acc 0.188
# [ 20/91] Train Loss 2.790 Acc 0.125
# [ 30/91] Train Loss 2.517 Acc 0.250
# [ 40/91] Train Loss 2.344 Acc 0.250
# [ 50/91] Train Loss 2.360 Acc 0.188
# [ 60/91] Train Loss 2.468 Acc 0.219
# [ 70/91] Train Loss 2.644 Acc 0.156
# [ 80/91] Train Loss 2.493 Acc 0.156
# [ 90/91] Train Loss 2.673 Acc 0.056
# Epoch  14/100 Train Loss 2.570 Acc 0.188
# ---------------- Testing ----------------
# Epoch  14/100 Test Loss 2.429 Acc 0.129
# ---------------- Epoch 15 ----------------
# [  0/91] Train Loss 2.560 Acc 0.188
# [ 10/91] Train Loss 2.856 Acc 0.188
# [ 20/91] Train Loss 2.571 Acc 0.219
# [ 30/91] Train Loss 2.204 Acc 0.344
# [ 40/91] Train Loss 2.401 Acc 0.219
# [ 50/91] Train Loss 2.502 Acc 0.219
# [ 60/91] Train Loss 2.503 Acc 0.156
# [ 70/91] Train Loss 2.593 Acc 0.156
# [ 80/91] Train Loss 2.555 Acc 0.281
# [ 90/91] Train Loss 2.570 Acc 0.222
# Epoch  15/100 Train Loss 2.525 Acc 0.205
# ---------------- Testing ----------------
# Epoch  15/100 Test Loss 2.371 Acc 0.355
# ---------------- Epoch 16 ----------------
# [  0/91] Train Loss 2.195 Acc 0.281
# [ 10/91] Train Loss 2.457 Acc 0.281
# [ 20/91] Train Loss 2.788 Acc 0.062
# [ 30/91] Train Loss 2.578 Acc 0.125
# [ 40/91] Train Loss 2.121 Acc 0.344
# [ 50/91] Train Loss 2.103 Acc 0.438
# [ 60/91] Train Loss 2.479 Acc 0.188
# [ 70/91] Train Loss 2.401 Acc 0.250
# [ 80/91] Train Loss 2.409 Acc 0.281
# [ 90/91] Train Loss 2.561 Acc 0.222
# Epoch  16/100 Train Loss 2.483 Acc 0.217
# ---------------- Testing ----------------
# Epoch  16/100 Test Loss 2.406 Acc 0.290
# ---------------- Epoch 17 ----------------
# [  0/91] Train Loss 2.503 Acc 0.219
# [ 10/91] Train Loss 2.367 Acc 0.250
# [ 20/91] Train Loss 2.666 Acc 0.094
# [ 30/91] Train Loss 2.477 Acc 0.250
# [ 40/91] Train Loss 2.257 Acc 0.250
# [ 50/91] Train Loss 2.308 Acc 0.281
# [ 60/91] Train Loss 2.493 Acc 0.188
# [ 70/91] Train Loss 2.633 Acc 0.250
# [ 80/91] Train Loss 2.547 Acc 0.219
# [ 90/91] Train Loss 2.391 Acc 0.111
# Epoch  17/100 Train Loss 2.485 Acc 0.209
# ---------------- Testing ----------------
# Epoch  17/100 Test Loss 2.396 Acc 0.194
# ---------------- Epoch 18 ----------------
# [  0/91] Train Loss 2.188 Acc 0.312
# [ 10/91] Train Loss 2.412 Acc 0.188
# [ 20/91] Train Loss 2.371 Acc 0.188
# [ 30/91] Train Loss 2.245 Acc 0.312
# [ 40/91] Train Loss 2.373 Acc 0.156
# [ 50/91] Train Loss 2.271 Acc 0.312
# [ 60/91] Train Loss 2.485 Acc 0.156
# [ 70/91] Train Loss 2.471 Acc 0.312
# [ 80/91] Train Loss 2.402 Acc 0.156
# [ 90/91] Train Loss 2.668 Acc 0.222
# Epoch  18/100 Train Loss 2.470 Acc 0.216
# ---------------- Testing ----------------
# Epoch  18/100 Test Loss 2.294 Acc 0.226
# ---------------- Epoch 19 ----------------
# [  0/91] Train Loss 2.262 Acc 0.312
# [ 10/91] Train Loss 2.354 Acc 0.188
# [ 20/91] Train Loss 2.366 Acc 0.312
# [ 30/91] Train Loss 2.174 Acc 0.375
# [ 40/91] Train Loss 2.202 Acc 0.250
# [ 50/91] Train Loss 2.423 Acc 0.219
# [ 60/91] Train Loss 2.322 Acc 0.281
# [ 70/91] Train Loss 2.211 Acc 0.375
# [ 80/91] Train Loss 2.396 Acc 0.219
# [ 90/91] Train Loss 2.726 Acc 0.167
# Epoch  19/100 Train Loss 2.440 Acc 0.227
# ---------------- Testing ----------------
# Epoch  19/100 Test Loss 2.388 Acc 0.226
# ---------------- Epoch 20 ----------------
# [  0/91] Train Loss 2.325 Acc 0.281
# [ 10/91] Train Loss 2.695 Acc 0.188
# [ 20/91] Train Loss 2.917 Acc 0.156
# [ 30/91] Train Loss 2.830 Acc 0.094
# [ 40/91] Train Loss 2.228 Acc 0.188
# [ 50/91] Train Loss 2.196 Acc 0.219
# [ 60/91] Train Loss 2.340 Acc 0.250
# [ 70/91] Train Loss 2.280 Acc 0.312
# [ 80/91] Train Loss 2.548 Acc 0.125
# [ 90/91] Train Loss 2.699 Acc 0.111
# Epoch  20/100 Train Loss 2.446 Acc 0.224
# ---------------- Testing ----------------
# Epoch  20/100 Test Loss 2.293 Acc 0.226
# ---------------- Epoch 21 ----------------
# [  0/91] Train Loss 2.368 Acc 0.219
# [ 10/91] Train Loss 2.604 Acc 0.188
# [ 20/91] Train Loss 2.846 Acc 0.156
# [ 30/91] Train Loss 2.402 Acc 0.219
# [ 40/91] Train Loss 2.601 Acc 0.156
# [ 50/91] Train Loss 2.342 Acc 0.281
# [ 60/91] Train Loss 2.286 Acc 0.281
# [ 70/91] Train Loss 2.281 Acc 0.250
# [ 80/91] Train Loss 2.469 Acc 0.250
# [ 90/91] Train Loss 2.397 Acc 0.222
# Epoch  21/100 Train Loss 2.417 Acc 0.226
# ---------------- Testing ----------------
# Epoch  21/100 Test Loss 2.266 Acc 0.129
# ---------------- Epoch 22 ----------------
# [  0/91] Train Loss 2.313 Acc 0.250
# [ 10/91] Train Loss 2.198 Acc 0.219
# [ 20/91] Train Loss 2.197 Acc 0.344
# [ 30/91] Train Loss 2.044 Acc 0.281
# [ 40/91] Train Loss 2.622 Acc 0.156
# [ 50/91] Train Loss 2.387 Acc 0.188
# [ 60/91] Train Loss 2.120 Acc 0.250
# [ 70/91] Train Loss 2.602 Acc 0.219
# [ 80/91] Train Loss 2.313 Acc 0.312
# [ 90/91] Train Loss 2.877 Acc 0.111
# Epoch  22/100 Train Loss 2.405 Acc 0.233
# ---------------- Testing ----------------
# Epoch  22/100 Test Loss 2.281 Acc 0.323
# ---------------- Epoch 23 ----------------
# [  0/91] Train Loss 2.625 Acc 0.125
# [ 10/91] Train Loss 2.287 Acc 0.188
# [ 20/91] Train Loss 2.221 Acc 0.250
# [ 30/91] Train Loss 2.453 Acc 0.219
# [ 40/91] Train Loss 2.050 Acc 0.344
# [ 50/91] Train Loss 2.419 Acc 0.219
# [ 60/91] Train Loss 2.235 Acc 0.250
# [ 70/91] Train Loss 2.259 Acc 0.406
# [ 80/91] Train Loss 2.816 Acc 0.156
# [ 90/91] Train Loss 2.331 Acc 0.111
# Epoch  23/100 Train Loss 2.374 Acc 0.239
# ---------------- Testing ----------------
# Epoch  23/100 Test Loss 2.280 Acc 0.161
# ---------------- Epoch 24 ----------------
# [  0/91] Train Loss 2.176 Acc 0.188
# [ 10/91] Train Loss 2.509 Acc 0.156
# [ 20/91] Train Loss 2.316 Acc 0.188
# [ 30/91] Train Loss 2.291 Acc 0.250
# [ 40/91] Train Loss 2.565 Acc 0.188
# [ 50/91] Train Loss 2.197 Acc 0.375
# [ 60/91] Train Loss 2.225 Acc 0.375
# [ 70/91] Train Loss 2.135 Acc 0.250
# [ 80/91] Train Loss 2.295 Acc 0.219
# [ 90/91] Train Loss 2.125 Acc 0.278
# Epoch  24/100 Train Loss 2.331 Acc 0.246
# ---------------- Testing ----------------
# Epoch  24/100 Test Loss 2.313 Acc 0.097
# ---------------- Epoch 25 ----------------
# [  0/91] Train Loss 2.184 Acc 0.312
# [ 10/91] Train Loss 2.825 Acc 0.156
# [ 20/91] Train Loss 2.383 Acc 0.281
# [ 30/91] Train Loss 2.251 Acc 0.219
# [ 40/91] Train Loss 2.623 Acc 0.125
# [ 50/91] Train Loss 2.025 Acc 0.375
# [ 60/91] Train Loss 2.499 Acc 0.219
# [ 70/91] Train Loss 2.284 Acc 0.219
# [ 80/91] Train Loss 2.233 Acc 0.281
# [ 90/91] Train Loss 2.541 Acc 0.167
# Epoch  25/100 Train Loss 2.353 Acc 0.248
# ---------------- Testing ----------------
# Epoch  25/100 Test Loss 2.241 Acc 0.194
# ---------------- Epoch 26 ----------------
# [  0/91] Train Loss 2.469 Acc 0.281
# [ 10/91] Train Loss 2.412 Acc 0.281
# [ 20/91] Train Loss 2.480 Acc 0.281
# [ 30/91] Train Loss 2.146 Acc 0.375
# [ 40/91] Train Loss 2.153 Acc 0.312
# [ 50/91] Train Loss 2.399 Acc 0.281
# [ 60/91] Train Loss 2.276 Acc 0.312
# [ 70/91] Train Loss 2.536 Acc 0.219
# [ 80/91] Train Loss 2.389 Acc 0.125
# [ 90/91] Train Loss 2.297 Acc 0.333
# Epoch  26/100 Train Loss 2.337 Acc 0.248
# ---------------- Testing ----------------
# Epoch  26/100 Test Loss 2.320 Acc 0.323
# ---------------- Epoch 27 ----------------
# [  0/91] Train Loss 2.247 Acc 0.219
# [ 10/91] Train Loss 2.207 Acc 0.250
# [ 20/91] Train Loss 2.730 Acc 0.031
# [ 30/91] Train Loss 2.566 Acc 0.219
# [ 40/91] Train Loss 2.372 Acc 0.156
# [ 50/91] Train Loss 2.643 Acc 0.188
# [ 60/91] Train Loss 2.396 Acc 0.250
# [ 70/91] Train Loss 2.370 Acc 0.219
# [ 80/91] Train Loss 2.346 Acc 0.188
# [ 90/91] Train Loss 2.512 Acc 0.167
# Epoch  27/100 Train Loss 2.321 Acc 0.252
# ---------------- Testing ----------------
# Epoch  27/100 Test Loss 2.254 Acc 0.355
# ---------------- Epoch 28 ----------------
# [  0/91] Train Loss 2.426 Acc 0.281
# [ 10/91] Train Loss 2.206 Acc 0.312
# [ 20/91] Train Loss 2.457 Acc 0.219
# [ 30/91] Train Loss 2.436 Acc 0.250
# [ 40/91] Train Loss 2.377 Acc 0.125
# [ 50/91] Train Loss 2.049 Acc 0.406
# [ 60/91] Train Loss 2.496 Acc 0.156
# [ 70/91] Train Loss 2.364 Acc 0.188
# [ 80/91] Train Loss 2.511 Acc 0.125
# [ 90/91] Train Loss 2.027 Acc 0.222
# Epoch  28/100 Train Loss 2.313 Acc 0.251
# ---------------- Testing ----------------
# Epoch  28/100 Test Loss 2.185 Acc 0.323
# ---------------- Epoch 29 ----------------
# [  0/91] Train Loss 2.073 Acc 0.281
# [ 10/91] Train Loss 2.070 Acc 0.281
# [ 20/91] Train Loss 1.935 Acc 0.219
# [ 30/91] Train Loss 2.129 Acc 0.375
# [ 40/91] Train Loss 2.417 Acc 0.250
# [ 50/91] Train Loss 2.269 Acc 0.344
# [ 60/91] Train Loss 2.403 Acc 0.219
# [ 70/91] Train Loss 2.049 Acc 0.281
# [ 80/91] Train Loss 2.307 Acc 0.219
# [ 90/91] Train Loss 2.289 Acc 0.333
# Epoch  29/100 Train Loss 2.280 Acc 0.265
# ---------------- Testing ----------------
# Epoch  29/100 Test Loss 2.177 Acc 0.290
# ---------------- Epoch 30 ----------------
# [  0/91] Train Loss 2.160 Acc 0.312
# [ 10/91] Train Loss 2.260 Acc 0.188
# [ 20/91] Train Loss 2.236 Acc 0.250
# [ 30/91] Train Loss 2.545 Acc 0.188
# [ 40/91] Train Loss 2.458 Acc 0.250
# [ 50/91] Train Loss 2.451 Acc 0.188
# [ 60/91] Train Loss 2.707 Acc 0.219
# [ 70/91] Train Loss 2.203 Acc 0.312
# [ 80/91] Train Loss 2.286 Acc 0.250
# [ 90/91] Train Loss 2.732 Acc 0.222
# Epoch  30/100 Train Loss 2.283 Acc 0.266
# ---------------- Testing ----------------
# Epoch  30/100 Test Loss 2.218 Acc 0.258
# ---------------- Epoch 31 ----------------
# [  0/91] Train Loss 2.119 Acc 0.156
# [ 10/91] Train Loss 2.358 Acc 0.219
# [ 20/91] Train Loss 2.304 Acc 0.156
# [ 30/91] Train Loss 2.042 Acc 0.281
# [ 40/91] Train Loss 2.215 Acc 0.250
# [ 50/91] Train Loss 2.764 Acc 0.188
# [ 60/91] Train Loss 2.095 Acc 0.312
# [ 70/91] Train Loss 2.421 Acc 0.281
# [ 80/91] Train Loss 2.215 Acc 0.250
# [ 90/91] Train Loss 2.258 Acc 0.278
# Epoch  31/100 Train Loss 2.280 Acc 0.269
# ---------------- Testing ----------------
# Epoch  31/100 Test Loss 2.132 Acc 0.387
# ---------------- Epoch 32 ----------------
# [  0/91] Train Loss 2.289 Acc 0.219
# [ 10/91] Train Loss 1.898 Acc 0.375
# [ 20/91] Train Loss 2.250 Acc 0.094
# [ 30/91] Train Loss 2.360 Acc 0.344
# [ 40/91] Train Loss 2.282 Acc 0.188
# [ 50/91] Train Loss 2.243 Acc 0.250
# [ 60/91] Train Loss 2.205 Acc 0.375
# [ 70/91] Train Loss 2.306 Acc 0.219
# [ 80/91] Train Loss 2.378 Acc 0.125
# [ 90/91] Train Loss 1.907 Acc 0.444
# Epoch  32/100 Train Loss 2.245 Acc 0.277
# ---------------- Testing ----------------
# Epoch  32/100 Test Loss 2.157 Acc 0.323
# ---------------- Epoch 33 ----------------
# [  0/91] Train Loss 2.221 Acc 0.406
# [ 10/91] Train Loss 1.811 Acc 0.438
# [ 20/91] Train Loss 1.892 Acc 0.375
# [ 30/91] Train Loss 2.083 Acc 0.219
# [ 40/91] Train Loss 2.232 Acc 0.250
# [ 50/91] Train Loss 2.072 Acc 0.281
# [ 60/91] Train Loss 2.027 Acc 0.344
# [ 70/91] Train Loss 1.961 Acc 0.406
# [ 80/91] Train Loss 1.997 Acc 0.375
# [ 90/91] Train Loss 1.832 Acc 0.333
# Epoch  33/100 Train Loss 2.216 Acc 0.291
# ---------------- Testing ----------------
# Epoch  33/100 Test Loss 2.208 Acc 0.323
# ---------------- Epoch 34 ----------------
# [  0/91] Train Loss 2.447 Acc 0.281
# [ 10/91] Train Loss 1.964 Acc 0.312
# [ 20/91] Train Loss 2.445 Acc 0.250
# [ 30/91] Train Loss 2.389 Acc 0.156
# [ 40/91] Train Loss 2.558 Acc 0.250
# [ 50/91] Train Loss 1.851 Acc 0.344
# [ 60/91] Train Loss 1.954 Acc 0.375
# [ 70/91] Train Loss 2.335 Acc 0.281
# [ 80/91] Train Loss 2.486 Acc 0.156
# [ 90/91] Train Loss 2.220 Acc 0.333
# Epoch  34/100 Train Loss 2.229 Acc 0.281
# ---------------- Testing ----------------
# Epoch  34/100 Test Loss 2.118 Acc 0.355
# ---------------- Epoch 35 ----------------
# [  0/91] Train Loss 2.199 Acc 0.344
# [ 10/91] Train Loss 2.436 Acc 0.281
# [ 20/91] Train Loss 2.320 Acc 0.281
# [ 30/91] Train Loss 2.379 Acc 0.219
# [ 40/91] Train Loss 2.171 Acc 0.281
# [ 50/91] Train Loss 1.952 Acc 0.406
# [ 60/91] Train Loss 2.337 Acc 0.250
# [ 70/91] Train Loss 2.355 Acc 0.312
# [ 80/91] Train Loss 2.024 Acc 0.344
# [ 90/91] Train Loss 2.001 Acc 0.333
# Epoch  35/100 Train Loss 2.208 Acc 0.293
# ---------------- Testing ----------------
# Epoch  35/100 Test Loss 2.075 Acc 0.290
# ---------------- Epoch 36 ----------------
# [  0/91] Train Loss 2.303 Acc 0.250
# [ 10/91] Train Loss 2.239 Acc 0.375
# [ 20/91] Train Loss 2.318 Acc 0.312
# [ 30/91] Train Loss 2.218 Acc 0.281
# [ 40/91] Train Loss 2.326 Acc 0.281
# [ 50/91] Train Loss 1.884 Acc 0.375
# [ 60/91] Train Loss 2.070 Acc 0.344
# [ 70/91] Train Loss 2.481 Acc 0.250
# [ 80/91] Train Loss 2.300 Acc 0.312
# [ 90/91] Train Loss 2.622 Acc 0.167
# Epoch  36/100 Train Loss 2.207 Acc 0.282
# ---------------- Testing ----------------
# Epoch  36/100 Test Loss 2.114 Acc 0.258
# ---------------- Epoch 37 ----------------
# [  0/91] Train Loss 2.274 Acc 0.250
# [ 10/91] Train Loss 2.045 Acc 0.312
# [ 20/91] Train Loss 1.926 Acc 0.375
# [ 30/91] Train Loss 2.216 Acc 0.219
# [ 40/91] Train Loss 2.191 Acc 0.312
# [ 50/91] Train Loss 2.393 Acc 0.219
# [ 60/91] Train Loss 1.806 Acc 0.500
# [ 70/91] Train Loss 2.297 Acc 0.312
# [ 80/91] Train Loss 1.971 Acc 0.406
# [ 90/91] Train Loss 2.000 Acc 0.222
# Epoch  37/100 Train Loss 2.183 Acc 0.298
# ---------------- Testing ----------------
# Epoch  37/100 Test Loss 2.049 Acc 0.290
# ---------------- Epoch 38 ----------------
# [  0/91] Train Loss 2.325 Acc 0.250
# [ 10/91] Train Loss 2.074 Acc 0.375
# [ 20/91] Train Loss 2.042 Acc 0.281
# [ 30/91] Train Loss 2.259 Acc 0.219
# [ 40/91] Train Loss 1.991 Acc 0.312
# [ 50/91] Train Loss 2.281 Acc 0.312
# [ 60/91] Train Loss 2.282 Acc 0.312
# [ 70/91] Train Loss 2.019 Acc 0.344
# [ 80/91] Train Loss 2.124 Acc 0.344
# [ 90/91] Train Loss 2.613 Acc 0.111
# Epoch  38/100 Train Loss 2.167 Acc 0.298
# ---------------- Testing ----------------
# Epoch  38/100 Test Loss 2.081 Acc 0.323
# ---------------- Epoch 39 ----------------
# [  0/91] Train Loss 1.964 Acc 0.344
# [ 10/91] Train Loss 2.644 Acc 0.250
# [ 20/91] Train Loss 2.359 Acc 0.219
# [ 30/91] Train Loss 1.777 Acc 0.531
# [ 40/91] Train Loss 2.129 Acc 0.438
# [ 50/91] Train Loss 2.069 Acc 0.312
# [ 60/91] Train Loss 1.752 Acc 0.375
# [ 70/91] Train Loss 2.611 Acc 0.188
# [ 80/91] Train Loss 2.162 Acc 0.344
# [ 90/91] Train Loss 2.214 Acc 0.333
# Epoch  39/100 Train Loss 2.161 Acc 0.304
# ---------------- Testing ----------------
# Epoch  39/100 Test Loss 2.004 Acc 0.355
# ---------------- Epoch 40 ----------------
# [  0/91] Train Loss 2.456 Acc 0.156
# [ 10/91] Train Loss 2.271 Acc 0.188
# [ 20/91] Train Loss 2.387 Acc 0.219
# [ 30/91] Train Loss 1.957 Acc 0.281
# [ 40/91] Train Loss 2.333 Acc 0.312
# [ 50/91] Train Loss 2.337 Acc 0.312
# [ 60/91] Train Loss 2.050 Acc 0.312
# [ 70/91] Train Loss 2.209 Acc 0.312
# [ 80/91] Train Loss 1.944 Acc 0.344
# [ 90/91] Train Loss 2.245 Acc 0.167
# Epoch  40/100 Train Loss 2.141 Acc 0.315
# ---------------- Testing ----------------
# Epoch  40/100 Test Loss 2.050 Acc 0.355
# ---------------- Epoch 41 ----------------
# [  0/91] Train Loss 1.992 Acc 0.406
# [ 10/91] Train Loss 2.140 Acc 0.469
# [ 20/91] Train Loss 2.393 Acc 0.250
# [ 30/91] Train Loss 2.480 Acc 0.219
# [ 40/91] Train Loss 1.947 Acc 0.344
# [ 50/91] Train Loss 1.861 Acc 0.281
# [ 60/91] Train Loss 1.906 Acc 0.438
# [ 70/91] Train Loss 1.981 Acc 0.281
# [ 80/91] Train Loss 2.168 Acc 0.281
# [ 90/91] Train Loss 2.292 Acc 0.111
# Epoch  41/100 Train Loss 2.128 Acc 0.310
# ---------------- Testing ----------------
# Epoch  41/100 Test Loss 2.117 Acc 0.323
# ---------------- Epoch 42 ----------------
# [  0/91] Train Loss 2.037 Acc 0.188
# [ 10/91] Train Loss 2.031 Acc 0.438
# [ 20/91] Train Loss 2.039 Acc 0.344
# [ 30/91] Train Loss 2.036 Acc 0.344
# [ 40/91] Train Loss 2.000 Acc 0.281
# [ 50/91] Train Loss 2.139 Acc 0.438
# [ 60/91] Train Loss 2.091 Acc 0.312
# [ 70/91] Train Loss 2.284 Acc 0.219
# [ 80/91] Train Loss 2.138 Acc 0.312
# [ 90/91] Train Loss 2.058 Acc 0.389
# Epoch  42/100 Train Loss 2.105 Acc 0.326
# ---------------- Testing ----------------
# Epoch  42/100 Test Loss 1.999 Acc 0.226
# ---------------- Epoch 43 ----------------
# [  0/91] Train Loss 2.238 Acc 0.281
# [ 10/91] Train Loss 2.211 Acc 0.312
# [ 20/91] Train Loss 2.212 Acc 0.375
# [ 30/91] Train Loss 2.471 Acc 0.219
# [ 40/91] Train Loss 2.088 Acc 0.344
# [ 50/91] Train Loss 1.911 Acc 0.438
# [ 60/91] Train Loss 1.981 Acc 0.312
# [ 70/91] Train Loss 2.073 Acc 0.250
# [ 80/91] Train Loss 2.491 Acc 0.375
# [ 90/91] Train Loss 1.941 Acc 0.278
# Epoch  43/100 Train Loss 2.086 Acc 0.340
# ---------------- Testing ----------------
# Epoch  43/100 Test Loss 1.995 Acc 0.323
# ---------------- Epoch 44 ----------------
# [  0/91] Train Loss 2.055 Acc 0.406
# [ 10/91] Train Loss 2.037 Acc 0.344
# [ 20/91] Train Loss 2.252 Acc 0.281
# [ 30/91] Train Loss 2.115 Acc 0.344
# [ 40/91] Train Loss 2.049 Acc 0.375
# [ 50/91] Train Loss 2.204 Acc 0.344
# [ 60/91] Train Loss 1.862 Acc 0.531
# [ 70/91] Train Loss 2.064 Acc 0.312
# [ 80/91] Train Loss 1.845 Acc 0.344
# [ 90/91] Train Loss 2.672 Acc 0.167
# Epoch  44/100 Train Loss 2.055 Acc 0.345
# ---------------- Testing ----------------
# Epoch  44/100 Test Loss 2.043 Acc 0.355
# ---------------- Epoch 45 ----------------
# [  0/91] Train Loss 2.095 Acc 0.281
# [ 10/91] Train Loss 2.407 Acc 0.250
# [ 20/91] Train Loss 1.784 Acc 0.438
# [ 30/91] Train Loss 1.999 Acc 0.312
# [ 40/91] Train Loss 1.965 Acc 0.375
# [ 50/91] Train Loss 2.214 Acc 0.156
# [ 60/91] Train Loss 1.932 Acc 0.375
# [ 70/91] Train Loss 2.154 Acc 0.250
# [ 80/91] Train Loss 1.989 Acc 0.375
# [ 90/91] Train Loss 1.849 Acc 0.500
# Epoch  45/100 Train Loss 2.080 Acc 0.327
# ---------------- Testing ----------------
# Epoch  45/100 Test Loss 1.984 Acc 0.258
# ---------------- Epoch 46 ----------------
# [  0/91] Train Loss 1.942 Acc 0.406
# [ 10/91] Train Loss 1.921 Acc 0.375
# [ 20/91] Train Loss 2.253 Acc 0.281
# [ 30/91] Train Loss 2.342 Acc 0.281
# [ 40/91] Train Loss 1.696 Acc 0.500
# [ 50/91] Train Loss 2.200 Acc 0.312
# [ 60/91] Train Loss 2.209 Acc 0.188
# [ 70/91] Train Loss 1.924 Acc 0.500
# [ 80/91] Train Loss 2.097 Acc 0.375
# [ 90/91] Train Loss 2.117 Acc 0.167
# Epoch  46/100 Train Loss 2.054 Acc 0.340
# ---------------- Testing ----------------
# Epoch  46/100 Test Loss 1.944 Acc 0.387
# ---------------- Epoch 47 ----------------
# [  0/91] Train Loss 2.012 Acc 0.375
# [ 10/91] Train Loss 1.962 Acc 0.406
# [ 20/91] Train Loss 2.649 Acc 0.156
# [ 30/91] Train Loss 2.005 Acc 0.438
# [ 40/91] Train Loss 2.063 Acc 0.344
# [ 50/91] Train Loss 1.859 Acc 0.375
# [ 60/91] Train Loss 1.917 Acc 0.375
# [ 70/91] Train Loss 1.747 Acc 0.438
# [ 80/91] Train Loss 2.099 Acc 0.312
# [ 90/91] Train Loss 1.701 Acc 0.278
# Epoch  47/100 Train Loss 2.061 Acc 0.346
# ---------------- Testing ----------------
# Epoch  47/100 Test Loss 1.948 Acc 0.452
# ---------------- Epoch 48 ----------------
# [  0/91] Train Loss 2.236 Acc 0.312
# [ 10/91] Train Loss 2.257 Acc 0.219
# [ 20/91] Train Loss 1.875 Acc 0.344
# [ 30/91] Train Loss 2.158 Acc 0.344
# [ 40/91] Train Loss 2.196 Acc 0.219
# [ 50/91] Train Loss 1.793 Acc 0.375
# [ 60/91] Train Loss 1.617 Acc 0.500
# [ 70/91] Train Loss 2.069 Acc 0.312
# [ 80/91] Train Loss 2.135 Acc 0.281
# [ 90/91] Train Loss 1.883 Acc 0.444
# Epoch  48/100 Train Loss 2.075 Acc 0.342
# ---------------- Testing ----------------
# Epoch  48/100 Test Loss 1.938 Acc 0.355
# ---------------- Epoch 49 ----------------
# [  0/91] Train Loss 1.891 Acc 0.469
# [ 10/91] Train Loss 1.828 Acc 0.375
# [ 20/91] Train Loss 1.701 Acc 0.438
# [ 30/91] Train Loss 1.877 Acc 0.469
# [ 40/91] Train Loss 1.986 Acc 0.312
# [ 50/91] Train Loss 1.920 Acc 0.438
# [ 60/91] Train Loss 1.818 Acc 0.406
# [ 70/91] Train Loss 2.120 Acc 0.344
# [ 80/91] Train Loss 1.892 Acc 0.438
# [ 90/91] Train Loss 1.975 Acc 0.444
# Epoch  49/100 Train Loss 2.015 Acc 0.354
# ---------------- Testing ----------------
# Epoch  49/100 Test Loss 1.914 Acc 0.387
# ---------------- Epoch 50 ----------------
# [  0/91] Train Loss 1.950 Acc 0.375
# [ 10/91] Train Loss 1.662 Acc 0.562
# [ 20/91] Train Loss 1.523 Acc 0.438
# [ 30/91] Train Loss 2.189 Acc 0.281
# [ 40/91] Train Loss 1.987 Acc 0.312
# [ 50/91] Train Loss 1.789 Acc 0.438
# [ 60/91] Train Loss 2.200 Acc 0.375
# [ 70/91] Train Loss 2.104 Acc 0.188
# [ 80/91] Train Loss 1.989 Acc 0.344
# [ 90/91] Train Loss 1.590 Acc 0.500
# Epoch  50/100 Train Loss 1.996 Acc 0.363
# ---------------- Testing ----------------
# Epoch  50/100 Test Loss 1.920 Acc 0.419
# ---------------- Epoch 51 ----------------
# [  0/91] Train Loss 2.145 Acc 0.219
# [ 10/91] Train Loss 2.012 Acc 0.312
# [ 20/91] Train Loss 1.940 Acc 0.250
# [ 30/91] Train Loss 1.974 Acc 0.406
# [ 40/91] Train Loss 1.798 Acc 0.500
# [ 50/91] Train Loss 1.972 Acc 0.438
# [ 60/91] Train Loss 2.179 Acc 0.312
# [ 70/91] Train Loss 1.781 Acc 0.531
# [ 80/91] Train Loss 2.295 Acc 0.281
# [ 90/91] Train Loss 2.053 Acc 0.278
# Epoch  51/100 Train Loss 2.002 Acc 0.364
# ---------------- Testing ----------------
# Epoch  51/100 Test Loss 1.872 Acc 0.387
# ---------------- Epoch 52 ----------------
# [  0/91] Train Loss 2.076 Acc 0.375
# [ 10/91] Train Loss 1.924 Acc 0.281
# [ 20/91] Train Loss 1.702 Acc 0.500
# [ 30/91] Train Loss 1.569 Acc 0.531
# [ 40/91] Train Loss 1.897 Acc 0.438
# [ 50/91] Train Loss 1.963 Acc 0.312
# [ 60/91] Train Loss 1.494 Acc 0.406
# [ 70/91] Train Loss 2.042 Acc 0.312
# [ 80/91] Train Loss 1.793 Acc 0.469
# [ 90/91] Train Loss 2.071 Acc 0.333
# Epoch  52/100 Train Loss 1.958 Acc 0.378
# ---------------- Testing ----------------
# Epoch  52/100 Test Loss 1.965 Acc 0.387
# ---------------- Epoch 53 ----------------
# [  0/91] Train Loss 2.045 Acc 0.312
# [ 10/91] Train Loss 1.798 Acc 0.469
# [ 20/91] Train Loss 1.915 Acc 0.438
# [ 30/91] Train Loss 2.235 Acc 0.250
# [ 40/91] Train Loss 1.907 Acc 0.469
# [ 50/91] Train Loss 2.004 Acc 0.281
# [ 60/91] Train Loss 2.289 Acc 0.281
# [ 70/91] Train Loss 2.145 Acc 0.281
# [ 80/91] Train Loss 2.067 Acc 0.344
# [ 90/91] Train Loss 1.918 Acc 0.500
# Epoch  53/100 Train Loss 1.972 Acc 0.367
# ---------------- Testing ----------------
# Epoch  53/100 Test Loss 1.847 Acc 0.452
# ---------------- Epoch 54 ----------------
# [  0/91] Train Loss 1.670 Acc 0.438
# [ 10/91] Train Loss 1.998 Acc 0.281
# [ 20/91] Train Loss 1.855 Acc 0.406
# [ 30/91] Train Loss 1.898 Acc 0.438
# [ 40/91] Train Loss 2.290 Acc 0.312
# [ 50/91] Train Loss 1.839 Acc 0.469
# [ 60/91] Train Loss 1.698 Acc 0.469
# [ 70/91] Train Loss 1.758 Acc 0.469
# [ 80/91] Train Loss 2.215 Acc 0.281
# [ 90/91] Train Loss 1.934 Acc 0.167
# Epoch  54/100 Train Loss 1.901 Acc 0.385
# ---------------- Testing ----------------
# Epoch  54/100 Test Loss 1.929 Acc 0.161
# ---------------- Epoch 55 ----------------
# [  0/91] Train Loss 1.673 Acc 0.469
# [ 10/91] Train Loss 1.973 Acc 0.344
# [ 20/91] Train Loss 1.741 Acc 0.406
# [ 30/91] Train Loss 1.822 Acc 0.344
# [ 40/91] Train Loss 1.760 Acc 0.375
# [ 50/91] Train Loss 1.861 Acc 0.469
# [ 60/91] Train Loss 1.856 Acc 0.500
# [ 70/91] Train Loss 1.724 Acc 0.438
# [ 80/91] Train Loss 2.132 Acc 0.281
# [ 90/91] Train Loss 2.157 Acc 0.278
# Epoch  55/100 Train Loss 1.967 Acc 0.371
# ---------------- Testing ----------------
# Epoch  55/100 Test Loss 1.871 Acc 0.290
# ---------------- Epoch 56 ----------------
# [  0/91] Train Loss 2.214 Acc 0.250
# [ 10/91] Train Loss 1.961 Acc 0.406
# [ 20/91] Train Loss 2.002 Acc 0.406
# [ 30/91] Train Loss 1.829 Acc 0.469
# [ 40/91] Train Loss 1.965 Acc 0.375
# [ 50/91] Train Loss 1.895 Acc 0.406
# [ 60/91] Train Loss 1.748 Acc 0.562
# [ 70/91] Train Loss 1.541 Acc 0.469
# [ 80/91] Train Loss 1.583 Acc 0.500
# [ 90/91] Train Loss 1.439 Acc 0.389
# Epoch  56/100 Train Loss 1.917 Acc 0.390
# ---------------- Testing ----------------
# Epoch  56/100 Test Loss 1.938 Acc 0.548
# ---------------- Epoch 57 ----------------
# [  0/91] Train Loss 2.090 Acc 0.375
# [ 10/91] Train Loss 1.798 Acc 0.438
# [ 20/91] Train Loss 2.027 Acc 0.406
# [ 30/91] Train Loss 1.722 Acc 0.438
# [ 40/91] Train Loss 1.662 Acc 0.469
# [ 50/91] Train Loss 1.712 Acc 0.469
# [ 60/91] Train Loss 1.964 Acc 0.406
# [ 70/91] Train Loss 1.932 Acc 0.344
# [ 80/91] Train Loss 1.966 Acc 0.281
# [ 90/91] Train Loss 1.452 Acc 0.556
# Epoch  57/100 Train Loss 1.911 Acc 0.395
# ---------------- Testing ----------------
# Epoch  57/100 Test Loss 1.847 Acc 0.387
# ---------------- Epoch 58 ----------------
# [  0/91] Train Loss 1.680 Acc 0.344
# [ 10/91] Train Loss 1.544 Acc 0.531
# [ 20/91] Train Loss 1.537 Acc 0.438
# [ 30/91] Train Loss 2.246 Acc 0.281
# [ 40/91] Train Loss 1.703 Acc 0.375
# [ 50/91] Train Loss 2.006 Acc 0.250
# [ 60/91] Train Loss 1.906 Acc 0.406
# [ 70/91] Train Loss 1.849 Acc 0.531
# [ 80/91] Train Loss 1.535 Acc 0.500
# [ 90/91] Train Loss 2.201 Acc 0.333
# Epoch  58/100 Train Loss 1.877 Acc 0.396
# ---------------- Testing ----------------
# Epoch  58/100 Test Loss 2.010 Acc 0.452
# ---------------- Epoch 59 ----------------
# [  0/91] Train Loss 1.644 Acc 0.500
# [ 10/91] Train Loss 2.185 Acc 0.250
# [ 20/91] Train Loss 1.836 Acc 0.406
# [ 30/91] Train Loss 2.171 Acc 0.375
# [ 40/91] Train Loss 1.919 Acc 0.344
# [ 50/91] Train Loss 2.153 Acc 0.250
# [ 60/91] Train Loss 1.937 Acc 0.406
# [ 70/91] Train Loss 2.024 Acc 0.312
# [ 80/91] Train Loss 1.989 Acc 0.500
# [ 90/91] Train Loss 1.927 Acc 0.389
# Epoch  59/100 Train Loss 1.885 Acc 0.411
# ---------------- Testing ----------------
# Epoch  59/100 Test Loss 1.856 Acc 0.387
# ---------------- Epoch 60 ----------------
# [  0/91] Train Loss 1.809 Acc 0.438
# [ 10/91] Train Loss 1.837 Acc 0.438
# [ 20/91] Train Loss 2.036 Acc 0.344
# [ 30/91] Train Loss 1.634 Acc 0.500
# [ 40/91] Train Loss 2.382 Acc 0.281
# [ 50/91] Train Loss 2.215 Acc 0.250
# [ 60/91] Train Loss 1.954 Acc 0.312
# [ 70/91] Train Loss 1.757 Acc 0.469
# [ 80/91] Train Loss 1.879 Acc 0.406
# [ 90/91] Train Loss 2.128 Acc 0.333
# Epoch  60/100 Train Loss 1.859 Acc 0.409
# ---------------- Testing ----------------
# Epoch  60/100 Test Loss 1.805 Acc 0.484
# ---------------- Epoch 61 ----------------
# [  0/91] Train Loss 1.837 Acc 0.375
# [ 10/91] Train Loss 1.901 Acc 0.500
# [ 20/91] Train Loss 1.407 Acc 0.500
# [ 30/91] Train Loss 1.913 Acc 0.344
# [ 40/91] Train Loss 1.564 Acc 0.469
# [ 50/91] Train Loss 1.627 Acc 0.406
# [ 60/91] Train Loss 2.221 Acc 0.375
# [ 70/91] Train Loss 1.890 Acc 0.438
# [ 80/91] Train Loss 1.931 Acc 0.406
# [ 90/91] Train Loss 2.073 Acc 0.278
# Epoch  61/100 Train Loss 1.846 Acc 0.409
# ---------------- Testing ----------------
# Epoch  61/100 Test Loss 1.856 Acc 0.548
# ---------------- Epoch 62 ----------------
# [  0/91] Train Loss 1.639 Acc 0.344
# [ 10/91] Train Loss 1.837 Acc 0.438
# [ 20/91] Train Loss 2.024 Acc 0.406
# [ 30/91] Train Loss 1.861 Acc 0.438
# [ 40/91] Train Loss 1.566 Acc 0.406
# [ 50/91] Train Loss 1.716 Acc 0.438
# [ 60/91] Train Loss 2.037 Acc 0.438
# [ 70/91] Train Loss 2.188 Acc 0.344
# [ 80/91] Train Loss 1.795 Acc 0.406
# [ 90/91] Train Loss 1.868 Acc 0.333
# Epoch  62/100 Train Loss 1.847 Acc 0.408
# ---------------- Testing ----------------
# Epoch  62/100 Test Loss 1.774 Acc 0.419
# ---------------- Epoch 63 ----------------
# [  0/91] Train Loss 1.795 Acc 0.375
# [ 10/91] Train Loss 1.751 Acc 0.469
# [ 20/91] Train Loss 1.751 Acc 0.500
# [ 30/91] Train Loss 1.887 Acc 0.406
# [ 40/91] Train Loss 1.982 Acc 0.250
# [ 50/91] Train Loss 1.805 Acc 0.438
# [ 60/91] Train Loss 1.753 Acc 0.406
# [ 70/91] Train Loss 1.969 Acc 0.438
# [ 80/91] Train Loss 1.666 Acc 0.531
# [ 90/91] Train Loss 1.305 Acc 0.611
# Epoch  63/100 Train Loss 1.814 Acc 0.416
# ---------------- Testing ----------------
# Epoch  63/100 Test Loss 1.789 Acc 0.387
# ---------------- Epoch 64 ----------------
# [  0/91] Train Loss 1.924 Acc 0.375
# [ 10/91] Train Loss 2.151 Acc 0.312
# [ 20/91] Train Loss 1.674 Acc 0.531
# [ 30/91] Train Loss 1.923 Acc 0.438
# [ 40/91] Train Loss 1.800 Acc 0.375
# [ 50/91] Train Loss 1.540 Acc 0.406
# [ 60/91] Train Loss 1.964 Acc 0.312
# [ 70/91] Train Loss 1.681 Acc 0.500
# [ 80/91] Train Loss 1.804 Acc 0.375
# [ 90/91] Train Loss 1.765 Acc 0.389
# Epoch  64/100 Train Loss 1.774 Acc 0.429
# ---------------- Testing ----------------
# Epoch  64/100 Test Loss 1.769 Acc 0.516
# ---------------- Epoch 65 ----------------
# [  0/91] Train Loss 1.804 Acc 0.406
# [ 10/91] Train Loss 1.832 Acc 0.562
# [ 20/91] Train Loss 1.543 Acc 0.469
# [ 30/91] Train Loss 1.774 Acc 0.469
# [ 40/91] Train Loss 1.878 Acc 0.344
# [ 50/91] Train Loss 1.509 Acc 0.375
# [ 60/91] Train Loss 1.340 Acc 0.469
# [ 70/91] Train Loss 1.270 Acc 0.656
# [ 80/91] Train Loss 1.944 Acc 0.406
# [ 90/91] Train Loss 2.170 Acc 0.278
# Epoch  65/100 Train Loss 1.789 Acc 0.432
# ---------------- Testing ----------------
# Epoch  65/100 Test Loss 1.746 Acc 0.484
# ---------------- Epoch 66 ----------------
# [  0/91] Train Loss 1.890 Acc 0.375
# [ 10/91] Train Loss 1.804 Acc 0.344
# [ 20/91] Train Loss 1.684 Acc 0.500
# [ 30/91] Train Loss 1.915 Acc 0.406
# [ 40/91] Train Loss 1.674 Acc 0.625
# [ 50/91] Train Loss 1.974 Acc 0.312
# [ 60/91] Train Loss 1.512 Acc 0.500
# [ 70/91] Train Loss 1.885 Acc 0.375
# [ 80/91] Train Loss 2.116 Acc 0.375
# [ 90/91] Train Loss 1.777 Acc 0.444
# Epoch  66/100 Train Loss 1.765 Acc 0.439
# ---------------- Testing ----------------
# Epoch  66/100 Test Loss 1.777 Acc 0.419
# ---------------- Epoch 67 ----------------
# [  0/91] Train Loss 1.549 Acc 0.562
# [ 10/91] Train Loss 1.589 Acc 0.438
# [ 20/91] Train Loss 1.296 Acc 0.562
# [ 30/91] Train Loss 2.080 Acc 0.344
# [ 40/91] Train Loss 1.592 Acc 0.531
# [ 50/91] Train Loss 1.780 Acc 0.469
# [ 60/91] Train Loss 1.716 Acc 0.406
# [ 70/91] Train Loss 2.061 Acc 0.281
# [ 80/91] Train Loss 1.886 Acc 0.312
# [ 90/91] Train Loss 1.876 Acc 0.389
# Epoch  67/100 Train Loss 1.765 Acc 0.433
# ---------------- Testing ----------------
# Epoch  67/100 Test Loss 1.815 Acc 0.452
# ---------------- Epoch 68 ----------------
# [  0/91] Train Loss 1.345 Acc 0.625
# [ 10/91] Train Loss 1.755 Acc 0.375
# [ 20/91] Train Loss 1.720 Acc 0.469
# [ 30/91] Train Loss 2.021 Acc 0.344
# [ 40/91] Train Loss 1.577 Acc 0.469
# [ 50/91] Train Loss 2.099 Acc 0.344
# [ 60/91] Train Loss 1.784 Acc 0.438
# [ 70/91] Train Loss 1.890 Acc 0.312
# [ 80/91] Train Loss 1.605 Acc 0.594
# [ 90/91] Train Loss 1.881 Acc 0.333
# Epoch  68/100 Train Loss 1.734 Acc 0.435
# ---------------- Testing ----------------
# Epoch  68/100 Test Loss 1.739 Acc 0.548
# ---------------- Epoch 69 ----------------
# [  0/91] Train Loss 1.708 Acc 0.500
# [ 10/91] Train Loss 1.588 Acc 0.406
# [ 20/91] Train Loss 1.675 Acc 0.375
# [ 30/91] Train Loss 1.976 Acc 0.250
# [ 40/91] Train Loss 1.414 Acc 0.562
# [ 50/91] Train Loss 1.755 Acc 0.406
# [ 60/91] Train Loss 1.775 Acc 0.438
# [ 70/91] Train Loss 1.585 Acc 0.531
# [ 80/91] Train Loss 1.473 Acc 0.531
# [ 90/91] Train Loss 1.966 Acc 0.389
# Epoch  69/100 Train Loss 1.729 Acc 0.453
# ---------------- Testing ----------------
# Epoch  69/100 Test Loss 1.754 Acc 0.645
# ---------------- Epoch 70 ----------------
# [  0/91] Train Loss 1.766 Acc 0.438
# [ 10/91] Train Loss 1.738 Acc 0.375
# [ 20/91] Train Loss 1.765 Acc 0.469
# [ 30/91] Train Loss 1.839 Acc 0.500
# [ 40/91] Train Loss 1.671 Acc 0.531
# [ 50/91] Train Loss 1.688 Acc 0.469
# [ 60/91] Train Loss 1.352 Acc 0.500
# [ 70/91] Train Loss 1.628 Acc 0.406
# [ 80/91] Train Loss 2.101 Acc 0.406
# [ 90/91] Train Loss 1.721 Acc 0.444
# Epoch  70/100 Train Loss 1.755 Acc 0.444
# ---------------- Testing ----------------
# Epoch  70/100 Test Loss 1.765 Acc 0.613
# ---------------- Epoch 71 ----------------
# [  0/91] Train Loss 1.460 Acc 0.531
# [ 10/91] Train Loss 1.590 Acc 0.438
# [ 20/91] Train Loss 1.794 Acc 0.531
# [ 30/91] Train Loss 1.532 Acc 0.438
# [ 40/91] Train Loss 1.206 Acc 0.625
# [ 50/91] Train Loss 1.850 Acc 0.500
# [ 60/91] Train Loss 1.531 Acc 0.562
# [ 70/91] Train Loss 1.777 Acc 0.438
# [ 80/91] Train Loss 1.341 Acc 0.656
# [ 90/91] Train Loss 1.827 Acc 0.500
# Epoch  71/100 Train Loss 1.692 Acc 0.472
# ---------------- Testing ----------------
# Epoch  71/100 Test Loss 1.698 Acc 0.452
# ---------------- Epoch 72 ----------------
# [  0/91] Train Loss 1.567 Acc 0.469
# [ 10/91] Train Loss 1.783 Acc 0.438
# [ 20/91] Train Loss 1.524 Acc 0.531
# [ 30/91] Train Loss 1.955 Acc 0.406
# [ 40/91] Train Loss 1.792 Acc 0.438
# [ 50/91] Train Loss 1.745 Acc 0.406
# [ 60/91] Train Loss 1.452 Acc 0.562
# [ 70/91] Train Loss 1.768 Acc 0.344
# [ 80/91] Train Loss 1.621 Acc 0.469
# [ 90/91] Train Loss 1.548 Acc 0.389
# Epoch  72/100 Train Loss 1.694 Acc 0.456
# ---------------- Testing ----------------
# Epoch  72/100 Test Loss 1.696 Acc 0.516
# ---------------- Epoch 73 ----------------
# [  0/91] Train Loss 1.809 Acc 0.438
# [ 10/91] Train Loss 1.643 Acc 0.438
# [ 20/91] Train Loss 2.029 Acc 0.312
# [ 30/91] Train Loss 2.137 Acc 0.281
# [ 40/91] Train Loss 1.923 Acc 0.469
# [ 50/91] Train Loss 1.821 Acc 0.438
# [ 60/91] Train Loss 1.812 Acc 0.375
# [ 70/91] Train Loss 1.866 Acc 0.406
# [ 80/91] Train Loss 1.382 Acc 0.500
# [ 90/91] Train Loss 2.188 Acc 0.222
# Epoch  73/100 Train Loss 1.696 Acc 0.458
# ---------------- Testing ----------------
# Epoch  73/100 Test Loss 1.742 Acc 0.645
# ---------------- Epoch 74 ----------------
# [  0/91] Train Loss 1.736 Acc 0.438
# [ 10/91] Train Loss 1.564 Acc 0.406
# [ 20/91] Train Loss 1.939 Acc 0.344
# [ 30/91] Train Loss 1.795 Acc 0.375
# [ 40/91] Train Loss 2.199 Acc 0.312
# [ 50/91] Train Loss 1.504 Acc 0.531
# [ 60/91] Train Loss 1.275 Acc 0.594
# [ 70/91] Train Loss 1.457 Acc 0.594
# [ 80/91] Train Loss 1.703 Acc 0.562
# [ 90/91] Train Loss 2.183 Acc 0.333
# Epoch  74/100 Train Loss 1.678 Acc 0.463
# ---------------- Testing ----------------
# Epoch  74/100 Test Loss 1.711 Acc 0.516
# ---------------- Epoch 75 ----------------
# [  0/91] Train Loss 1.605 Acc 0.469
# [ 10/91] Train Loss 1.450 Acc 0.438
# [ 20/91] Train Loss 1.606 Acc 0.594
# [ 30/91] Train Loss 1.856 Acc 0.406
# [ 40/91] Train Loss 1.474 Acc 0.469
# [ 50/91] Train Loss 1.439 Acc 0.438
# [ 60/91] Train Loss 1.736 Acc 0.406
# [ 70/91] Train Loss 1.393 Acc 0.469
# [ 80/91] Train Loss 1.850 Acc 0.469
# [ 90/91] Train Loss 2.248 Acc 0.222
# Epoch  75/100 Train Loss 1.698 Acc 0.456
# ---------------- Testing ----------------
# Epoch  75/100 Test Loss 1.760 Acc 0.258
# ---------------- Epoch 76 ----------------
# [  0/91] Train Loss 1.883 Acc 0.500
# [ 10/91] Train Loss 1.949 Acc 0.375
# [ 20/91] Train Loss 1.287 Acc 0.562
# [ 30/91] Train Loss 1.654 Acc 0.562
# [ 40/91] Train Loss 1.769 Acc 0.406
# [ 50/91] Train Loss 1.729 Acc 0.500
# [ 60/91] Train Loss 1.736 Acc 0.469
# [ 70/91] Train Loss 1.520 Acc 0.500
# [ 80/91] Train Loss 1.748 Acc 0.406
# [ 90/91] Train Loss 1.220 Acc 0.667
# Epoch  76/100 Train Loss 1.651 Acc 0.479
# ---------------- Testing ----------------
# Epoch  76/100 Test Loss 1.710 Acc 0.581
# ---------------- Epoch 77 ----------------
# [  0/91] Train Loss 1.187 Acc 0.719
# [ 10/91] Train Loss 1.835 Acc 0.406
# [ 20/91] Train Loss 1.765 Acc 0.406
# [ 30/91] Train Loss 1.595 Acc 0.469
# [ 40/91] Train Loss 1.856 Acc 0.500
# [ 50/91] Train Loss 1.432 Acc 0.500
# [ 60/91] Train Loss 1.823 Acc 0.562
# [ 70/91] Train Loss 1.327 Acc 0.594
# [ 80/91] Train Loss 2.019 Acc 0.312
# [ 90/91] Train Loss 1.819 Acc 0.389
# Epoch  77/100 Train Loss 1.632 Acc 0.482
# ---------------- Testing ----------------
# Epoch  77/100 Test Loss 1.722 Acc 0.516
# ---------------- Epoch 78 ----------------
# [  0/91] Train Loss 1.864 Acc 0.406
# [ 10/91] Train Loss 1.325 Acc 0.531
# [ 20/91] Train Loss 1.477 Acc 0.469
# [ 30/91] Train Loss 1.332 Acc 0.656
# [ 40/91] Train Loss 1.771 Acc 0.531
# [ 50/91] Train Loss 1.406 Acc 0.625
# [ 60/91] Train Loss 1.287 Acc 0.625
# [ 70/91] Train Loss 1.751 Acc 0.500
# [ 80/91] Train Loss 1.690 Acc 0.406
# [ 90/91] Train Loss 2.294 Acc 0.278
# Epoch  78/100 Train Loss 1.637 Acc 0.478
# ---------------- Testing ----------------
# Epoch  78/100 Test Loss 1.742 Acc 0.452
# ---------------- Epoch 79 ----------------
# [  0/91] Train Loss 1.547 Acc 0.500
# [ 10/91] Train Loss 1.837 Acc 0.406
# [ 20/91] Train Loss 1.515 Acc 0.531
# [ 30/91] Train Loss 1.243 Acc 0.531
# [ 40/91] Train Loss 1.719 Acc 0.469
# [ 50/91] Train Loss 1.529 Acc 0.438
# [ 60/91] Train Loss 1.536 Acc 0.469
# [ 70/91] Train Loss 2.151 Acc 0.312
# [ 80/91] Train Loss 1.278 Acc 0.625
# [ 90/91] Train Loss 1.304 Acc 0.667
# Epoch  79/100 Train Loss 1.615 Acc 0.496
# ---------------- Testing ----------------
# Epoch  79/100 Test Loss 1.715 Acc 0.323
# ---------------- Epoch 80 ----------------
# [  0/91] Train Loss 1.619 Acc 0.500
# [ 10/91] Train Loss 1.531 Acc 0.469
# [ 20/91] Train Loss 1.668 Acc 0.281
# [ 30/91] Train Loss 1.373 Acc 0.531
# [ 40/91] Train Loss 1.644 Acc 0.531
# [ 50/91] Train Loss 1.477 Acc 0.531
# [ 60/91] Train Loss 1.933 Acc 0.406
# [ 70/91] Train Loss 2.138 Acc 0.250
# [ 80/91] Train Loss 1.523 Acc 0.531
# [ 90/91] Train Loss 1.665 Acc 0.389
# Epoch  80/100 Train Loss 1.613 Acc 0.478
# ---------------- Testing ----------------
# Epoch  80/100 Test Loss 1.752 Acc 0.419
# ---------------- Epoch 81 ----------------
# [  0/91] Train Loss 1.564 Acc 0.469
# [ 10/91] Train Loss 1.409 Acc 0.500
# [ 20/91] Train Loss 1.381 Acc 0.562
# [ 30/91] Train Loss 1.555 Acc 0.594
# [ 40/91] Train Loss 1.050 Acc 0.688
# [ 50/91] Train Loss 1.752 Acc 0.594
# [ 60/91] Train Loss 1.626 Acc 0.531
# [ 70/91] Train Loss 1.531 Acc 0.594
# [ 80/91] Train Loss 1.602 Acc 0.469
# [ 90/91] Train Loss 1.397 Acc 0.500
# Epoch  81/100 Train Loss 1.568 Acc 0.499
# ---------------- Testing ----------------
# Epoch  81/100 Test Loss 1.658 Acc 0.548
# ---------------- Epoch 82 ----------------
# [  0/91] Train Loss 1.353 Acc 0.531
# [ 10/91] Train Loss 1.984 Acc 0.469
# [ 20/91] Train Loss 1.162 Acc 0.656
# [ 30/91] Train Loss 1.524 Acc 0.469
# [ 40/91] Train Loss 1.679 Acc 0.531
# [ 50/91] Train Loss 1.532 Acc 0.531
# [ 60/91] Train Loss 1.399 Acc 0.469
# [ 70/91] Train Loss 1.771 Acc 0.469
# [ 80/91] Train Loss 1.621 Acc 0.375
# [ 90/91] Train Loss 2.125 Acc 0.389
# Epoch  82/100 Train Loss 1.592 Acc 0.483
# ---------------- Testing ----------------
# Epoch  82/100 Test Loss 1.799 Acc 0.484
# ---------------- Epoch 83 ----------------
# [  0/91] Train Loss 1.440 Acc 0.594
# [ 10/91] Train Loss 1.399 Acc 0.594
# [ 20/91] Train Loss 1.835 Acc 0.438
# [ 30/91] Train Loss 1.699 Acc 0.469
# [ 40/91] Train Loss 1.586 Acc 0.469
# [ 50/91] Train Loss 1.768 Acc 0.438
# [ 60/91] Train Loss 1.781 Acc 0.406
# [ 70/91] Train Loss 1.545 Acc 0.438
# [ 80/91] Train Loss 1.830 Acc 0.375
# [ 90/91] Train Loss 1.303 Acc 0.556
# Epoch  83/100 Train Loss 1.568 Acc 0.501
# ---------------- Testing ----------------
# Epoch  83/100 Test Loss 1.694 Acc 0.452
# ---------------- Epoch 84 ----------------
# [  0/91] Train Loss 1.579 Acc 0.562
# [ 10/91] Train Loss 1.647 Acc 0.406
# [ 20/91] Train Loss 1.481 Acc 0.500
# [ 30/91] Train Loss 1.452 Acc 0.625
# [ 40/91] Train Loss 1.970 Acc 0.375
# [ 50/91] Train Loss 1.363 Acc 0.656
# [ 60/91] Train Loss 1.477 Acc 0.531
# [ 70/91] Train Loss 1.700 Acc 0.500
# [ 80/91] Train Loss 1.134 Acc 0.625
# [ 90/91] Train Loss 2.047 Acc 0.556
# Epoch  84/100 Train Loss 1.550 Acc 0.508
# ---------------- Testing ----------------
# Epoch  84/100 Test Loss 1.629 Acc 0.774
# ---------------- Epoch 85 ----------------
# [  0/91] Train Loss 1.702 Acc 0.438
# [ 10/91] Train Loss 1.530 Acc 0.531
# [ 20/91] Train Loss 1.252 Acc 0.719
# [ 30/91] Train Loss 1.349 Acc 0.625
# [ 40/91] Train Loss 1.536 Acc 0.562
# [ 50/91] Train Loss 1.590 Acc 0.562
# [ 60/91] Train Loss 1.420 Acc 0.562
# [ 70/91] Train Loss 1.628 Acc 0.406
# [ 80/91] Train Loss 1.591 Acc 0.469
# [ 90/91] Train Loss 1.210 Acc 0.667
# Epoch  85/100 Train Loss 1.561 Acc 0.507
# ---------------- Testing ----------------
# Epoch  85/100 Test Loss 1.687 Acc 0.419
# ---------------- Epoch 86 ----------------
# [  0/91] Train Loss 1.713 Acc 0.438
# [ 10/91] Train Loss 1.231 Acc 0.594
# [ 20/91] Train Loss 1.533 Acc 0.469
# [ 30/91] Train Loss 1.448 Acc 0.531
# [ 40/91] Train Loss 1.448 Acc 0.531
# [ 50/91] Train Loss 1.911 Acc 0.438
# [ 60/91] Train Loss 1.667 Acc 0.469
# [ 70/91] Train Loss 1.285 Acc 0.531
# [ 80/91] Train Loss 1.739 Acc 0.438
# [ 90/91] Train Loss 1.433 Acc 0.500
# Epoch  86/100 Train Loss 1.544 Acc 0.503
# ---------------- Testing ----------------
# Epoch  86/100 Test Loss 1.710 Acc 0.484
# ---------------- Epoch 87 ----------------
# [  0/91] Train Loss 1.417 Acc 0.562
# [ 10/91] Train Loss 1.156 Acc 0.562
# [ 20/91] Train Loss 1.573 Acc 0.438
# [ 30/91] Train Loss 1.494 Acc 0.406
# [ 40/91] Train Loss 1.748 Acc 0.438
# [ 50/91] Train Loss 1.616 Acc 0.531
# [ 60/91] Train Loss 1.459 Acc 0.531
# [ 70/91] Train Loss 1.840 Acc 0.406
# [ 80/91] Train Loss 1.763 Acc 0.469
# [ 90/91] Train Loss 1.819 Acc 0.556
# Epoch  87/100 Train Loss 1.556 Acc 0.502
# ---------------- Testing ----------------
# Epoch  87/100 Test Loss 1.655 Acc 0.581
# ---------------- Epoch 88 ----------------
# [  0/91] Train Loss 1.398 Acc 0.500
# [ 10/91] Train Loss 1.337 Acc 0.562
# [ 20/91] Train Loss 1.339 Acc 0.625
# [ 30/91] Train Loss 1.465 Acc 0.500
# [ 40/91] Train Loss 1.891 Acc 0.406
# [ 50/91] Train Loss 1.868 Acc 0.438
# [ 60/91] Train Loss 1.652 Acc 0.562
# [ 70/91] Train Loss 1.600 Acc 0.438
# [ 80/91] Train Loss 1.585 Acc 0.594
# [ 90/91] Train Loss 1.524 Acc 0.556
# Epoch  88/100 Train Loss 1.537 Acc 0.510
# ---------------- Testing ----------------
# Epoch  88/100 Test Loss 1.713 Acc 0.516
# ---------------- Epoch 89 ----------------
# [  0/91] Train Loss 1.691 Acc 0.469
# [ 10/91] Train Loss 1.578 Acc 0.438
# [ 20/91] Train Loss 1.389 Acc 0.469
# [ 30/91] Train Loss 1.524 Acc 0.531
# [ 40/91] Train Loss 1.325 Acc 0.625
# [ 50/91] Train Loss 1.439 Acc 0.500
# [ 60/91] Train Loss 1.587 Acc 0.500
# [ 70/91] Train Loss 1.614 Acc 0.438
# [ 80/91] Train Loss 1.397 Acc 0.625
# [ 90/91] Train Loss 1.842 Acc 0.278
# Epoch  89/100 Train Loss 1.508 Acc 0.515
# ---------------- Testing ----------------
# Epoch  89/100 Test Loss 1.703 Acc 0.484
# ---------------- Epoch 90 ----------------
# [  0/91] Train Loss 1.733 Acc 0.500
# [ 10/91] Train Loss 1.261 Acc 0.656
# [ 20/91] Train Loss 1.293 Acc 0.594
# [ 30/91] Train Loss 1.486 Acc 0.500
# [ 40/91] Train Loss 1.362 Acc 0.625
# [ 50/91] Train Loss 1.462 Acc 0.500
# [ 60/91] Train Loss 1.533 Acc 0.594
# [ 70/91] Train Loss 1.619 Acc 0.438
# [ 80/91] Train Loss 1.344 Acc 0.656
# [ 90/91] Train Loss 1.282 Acc 0.611
# Epoch  90/100 Train Loss 1.523 Acc 0.524
# ---------------- Testing ----------------
# Epoch  90/100 Test Loss 1.633 Acc 0.419
# ---------------- Epoch 91 ----------------
# [  0/91] Train Loss 1.758 Acc 0.500
# [ 10/91] Train Loss 1.564 Acc 0.531
# [ 20/91] Train Loss 1.060 Acc 0.625
# [ 30/91] Train Loss 1.587 Acc 0.406
# [ 40/91] Train Loss 1.929 Acc 0.375
# [ 50/91] Train Loss 1.824 Acc 0.469
# [ 60/91] Train Loss 1.130 Acc 0.625
# [ 70/91] Train Loss 1.757 Acc 0.531
# [ 80/91] Train Loss 1.640 Acc 0.406
# [ 90/91] Train Loss 2.008 Acc 0.500
# Epoch  91/100 Train Loss 1.533 Acc 0.516
# ---------------- Testing ----------------
# Epoch  91/100 Test Loss 1.703 Acc 0.419
# ---------------- Epoch 92 ----------------
# [  0/91] Train Loss 1.308 Acc 0.594
# [ 10/91] Train Loss 1.433 Acc 0.531
# [ 20/91] Train Loss 1.594 Acc 0.406
# [ 30/91] Train Loss 1.326 Acc 0.562
# [ 40/91] Train Loss 1.331 Acc 0.500
# [ 50/91] Train Loss 1.486 Acc 0.562
# [ 60/91] Train Loss 1.553 Acc 0.438
# [ 70/91] Train Loss 1.374 Acc 0.562
# [ 80/91] Train Loss 1.385 Acc 0.531
# [ 90/91] Train Loss 1.369 Acc 0.611
# Epoch  92/100 Train Loss 1.454 Acc 0.539
# ---------------- Testing ----------------
# Epoch  92/100 Test Loss 1.716 Acc 0.613
# ---------------- Epoch 93 ----------------
# [  0/91] Train Loss 1.267 Acc 0.500
# [ 10/91] Train Loss 1.481 Acc 0.562
# [ 20/91] Train Loss 1.179 Acc 0.688
# [ 30/91] Train Loss 1.079 Acc 0.562
# [ 40/91] Train Loss 1.313 Acc 0.625
# [ 50/91] Train Loss 1.608 Acc 0.375
# [ 60/91] Train Loss 1.557 Acc 0.531
# [ 70/91] Train Loss 1.280 Acc 0.656
# [ 80/91] Train Loss 2.109 Acc 0.344
# [ 90/91] Train Loss 1.431 Acc 0.611
# Epoch  93/100 Train Loss 1.478 Acc 0.536
# ---------------- Testing ----------------
# Epoch  93/100 Test Loss 1.685 Acc 0.452
# ---------------- Epoch 94 ----------------
# [  0/91] Train Loss 1.289 Acc 0.562
# [ 10/91] Train Loss 1.542 Acc 0.500
# [ 20/91] Train Loss 1.532 Acc 0.500
# [ 30/91] Train Loss 1.624 Acc 0.531
# [ 40/91] Train Loss 2.017 Acc 0.406
# [ 50/91] Train Loss 1.289 Acc 0.562
# [ 60/91] Train Loss 1.412 Acc 0.500
# [ 70/91] Train Loss 1.676 Acc 0.500
# [ 80/91] Train Loss 1.471 Acc 0.469
# [ 90/91] Train Loss 1.853 Acc 0.389
# Epoch  94/100 Train Loss 1.427 Acc 0.554
# ---------------- Testing ----------------
# Epoch  94/100 Test Loss 1.671 Acc 0.452
# ---------------- Epoch 95 ----------------
# [  0/91] Train Loss 1.805 Acc 0.438
# [ 10/91] Train Loss 1.525 Acc 0.562
# [ 20/91] Train Loss 1.495 Acc 0.500
# [ 30/91] Train Loss 1.371 Acc 0.500
# [ 40/91] Train Loss 1.311 Acc 0.594
# [ 50/91] Train Loss 1.244 Acc 0.656
# [ 60/91] Train Loss 1.419 Acc 0.531
# [ 70/91] Train Loss 1.196 Acc 0.594
# [ 80/91] Train Loss 1.712 Acc 0.469
# [ 90/91] Train Loss 1.736 Acc 0.389
# Epoch  95/100 Train Loss 1.473 Acc 0.531
# ---------------- Testing ----------------
# Epoch  95/100 Test Loss 1.711 Acc 0.323
# ---------------- Epoch 96 ----------------
# [  0/91] Train Loss 1.220 Acc 0.625
# [ 10/91] Train Loss 1.493 Acc 0.406
# [ 20/91] Train Loss 1.422 Acc 0.531
# [ 30/91] Train Loss 1.359 Acc 0.531
# [ 40/91] Train Loss 1.528 Acc 0.375
# [ 50/91] Train Loss 1.213 Acc 0.562
# [ 60/91] Train Loss 1.218 Acc 0.594
# [ 70/91] Train Loss 1.210 Acc 0.656
# [ 80/91] Train Loss 1.307 Acc 0.594
# [ 90/91] Train Loss 1.524 Acc 0.556
# Epoch  96/100 Train Loss 1.423 Acc 0.537
# ---------------- Testing ----------------
# Epoch  96/100 Test Loss 1.637 Acc 0.548
# ---------------- Epoch 97 ----------------
# [  0/91] Train Loss 1.882 Acc 0.438
# [ 10/91] Train Loss 1.342 Acc 0.594
# [ 20/91] Train Loss 1.748 Acc 0.469
# [ 30/91] Train Loss 1.994 Acc 0.281
# [ 40/91] Train Loss 1.322 Acc 0.500
# [ 50/91] Train Loss 1.353 Acc 0.594
# [ 60/91] Train Loss 1.627 Acc 0.469
# [ 70/91] Train Loss 1.483 Acc 0.500
# [ 80/91] Train Loss 1.383 Acc 0.562
# [ 90/91] Train Loss 1.390 Acc 0.611
# Epoch  97/100 Train Loss 1.431 Acc 0.539
# ---------------- Testing ----------------
# Epoch  97/100 Test Loss 1.657 Acc 0.387
# ---------------- Epoch 98 ----------------
# [  0/91] Train Loss 1.578 Acc 0.469
# [ 10/91] Train Loss 1.252 Acc 0.562
# [ 20/91] Train Loss 1.577 Acc 0.500
# [ 30/91] Train Loss 1.380 Acc 0.562
# [ 40/91] Train Loss 1.055 Acc 0.594
# [ 50/91] Train Loss 1.520 Acc 0.594
# [ 60/91] Train Loss 1.572 Acc 0.469
# [ 70/91] Train Loss 1.459 Acc 0.531
# [ 80/91] Train Loss 1.582 Acc 0.438
# [ 90/91] Train Loss 2.097 Acc 0.278
# Epoch  98/100 Train Loss 1.389 Acc 0.554
# ---------------- Testing ----------------
# Epoch  98/100 Test Loss 1.704 Acc 0.548
# ---------------- Epoch 99 ----------------
# [  0/91] Train Loss 1.732 Acc 0.375
# [ 10/91] Train Loss 1.518 Acc 0.438
# [ 20/91] Train Loss 1.254 Acc 0.594
# [ 30/91] Train Loss 1.605 Acc 0.469
# [ 40/91] Train Loss 1.561 Acc 0.500
# [ 50/91] Train Loss 1.674 Acc 0.469
# [ 60/91] Train Loss 1.690 Acc 0.469
# [ 70/91] Train Loss 1.227 Acc 0.688
# [ 80/91] Train Loss 1.538 Acc 0.500
# [ 90/91] Train Loss 1.260 Acc 0.500
# Epoch  99/100 Train Loss 1.446 Acc 0.534
# ---------------- Testing ----------------
# Epoch  99/100 Test Loss 1.764 Acc 0.613
# ---------------- Epoch 100 ----------------
# [  0/91] Train Loss 1.650 Acc 0.438
# [ 10/91] Train Loss 1.459 Acc 0.625
# [ 20/91] Train Loss 1.119 Acc 0.562
# [ 30/91] Train Loss 1.110 Acc 0.688
# [ 40/91] Train Loss 1.285 Acc 0.656
# [ 50/91] Train Loss 1.421 Acc 0.656
# [ 60/91] Train Loss 1.894 Acc 0.500
# [ 70/91] Train Loss 1.793 Acc 0.438
# [ 80/91] Train Loss 1.211 Acc 0.719
# [ 90/91] Train Loss 1.531 Acc 0.556
# Epoch 100/100 Train Loss 1.387 Acc 0.567
# ---------------- Testing ----------------
# Epoch 100/100 Test Loss 1.658 Acc 0.548
# --------------------
# The Best accuracy is 0.774 at epoch 84

# %% [markdown]
# ### 3.3 儲存模型
# PyTorch 提供 ```torch.save()``` API 可以儲存模型。
#
# PyTorch 建議使用 ```state_dict``` 來儲存模型(要存整個模型也可以)，```state_dict``` 包含模型的可學習參數(如 conv layers 的 weight 和 bias) 以及 registered buffer (如 batchnorm running mean) 。 由於 ```state_dict``` 屬於 python dictionaries ，所以有很大的使用彈性。
#
# 這裡我們只儲存最後的模型狀態，你也可以在每一個 epoch 後儲存一個節點或儲存擁有最佳表現的模型。常用的附檔名為 ```.pt``` 或 ```.pth```。
#
# 請完成以下 ? 處。

# %%
save_path = 'mymodel.pth'
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ### 3.4 繪製訓練過程的 loss 與 accuracy 變化
# 在訓練過程中，我們透過 ```list``` 儲存每個 epoch 的 loss 和 accuracy，現在透過 ```matplotlib.pyplot``` 將這些數值畫成圖表，可以幫助我們分析訓練過程的變化。
#
# 請完成以下 ? 處

# %%
# plotting loss curves
x = list(range(EPOCHS))
plt.plot(x, train_loss, x, test_loss)
plt.title('Training & Testing Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Testing'])
plt.show()

# %%
# plotting acc curves
x = list(range(EPOCHS))
plt.plot(x, train_acc, x, test_acc)
plt.title('Training & Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Testing'])
plt.show()

# %% [markdown]
# ## 參考資料 & 教學
#
# ### Transformations
# + https://pytorch.org/tutorials/beginner/basics/transforms_tutorial.html
# + https://pytorch.org/vision/stable/transforms.html 可以知道每種方法產生的效果
# + https://chih-sheng-huang821.medium.com/03-pytorch-dataaug-a712a7a7f55e
#
# ### Dataset
# + https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class
# + https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files
#
# ### Dataloader
# + https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#preparing-your-data-for-training-with-dataloaders
#
# ### Model
# #### Module
# + https://pytorch.org/docs/stable/generated/torch.nn.Module.html
# + https://pytorch.org/docs/stable/nn.html (conv, batchnorm, pooling layer 的詳細用法可以在這裡找到)
#
# #### Custom Model
# + https://pytorch.org/tutorials/beginner/examples_nn/two_layer_net_module.html
#
# #### nn.Sequential
# + https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html
#
# ### Training
# #### Optimizer
# + https://pytorch.org/docs/stable/optim.html
#
# #### Loss function
# + https://pytorch.org/docs/stable/nn.html#loss-functions
#
#
# #### Saving model
# + https://pytorch.org/tutorials/beginner/saving_loading_models.html
